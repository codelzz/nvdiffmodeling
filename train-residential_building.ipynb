# %% [markdown]
# # Nvdiffmodeling 算法测试
#
# [GitHub](https://github.com/NVlabs/nvdiffmodeling) | [Paper](https://research.nvidia.com/publication/2021-04_appearance-driven-automatic-3d-model-simplification) | [Video](https://d1qx31qr3h6wln.cloudfront.net/publications/autolod_video.mp4)

# %% [markdown]
# 问题：
# 1. 为什么Radius参数会用于camera eye位置初始化？
# 2. 为什么加载json配置文件覆盖camera eye设置后不需要变更对应的radius？
# 3. FLAGS.layers 代表什么？

# %%
import os
import sys
import time
import argparse
import json

import numpy as np
import torch
import torch.nn.functional as F
import nvdiffrast.torch as dr

import src.renderutils as ru
from src import obj
from src import util
from src import mesh
from src import texture
from src import render
from src import regularizer
from src.mesh import Mesh
from src import helper

import matplotlib.pyplot as plt
# Out:
# Using C:\Users\zhong\AppData\Local\torch_extensions\torch_extensions\Cache\py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file C:\Users\zhong\AppData\Local\torch_extensions\torch_extensions\Cache\py310_cu121\renderutils_plugin\build.ninja...
# Building extension module renderutils_plugin...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module renderutils_plugin...

# %% [markdown]
# ## 全局参数加载

# %%
CONFIG_FILE = "configs/residential_buildings.json"
FLAGS = helper.init_flags(args=['--config', CONFIG_FILE], show=False)
FLAGS
# Out:
# Namespace(iter=10000, batch=8, spp=1, layers=1, train_res=512, random_train_res=False, display_res=512, texture_res=[1024, 1024], display_interval=0, save_interval=10, learning_rate=0.01, light_power=5.0, min_roughness=0.08, subdivision=0, custom_mip=False, random_textures=False, laplacian_factor=None, relative_laplacian=False, background='checker', loss='logl1', out_dir='out/residential_buildings', config='configs/residential_buildings.json', ref_mesh='data/residential_buildings/residential_buildings_001.obj', base_mesh='data/sphere.obj', radius=3.5, camera_eye=[2.5, 0.0, -2.5], camera_up=[0.0, 1.0, 0.0], skip_train=['kd', 'ks'], displacement=0.15, mtl_override=None, proj_mtx=array([[ 2.5     ,  0.      ,  0.      ,  0.      ],
#        [ 0.      , -2.5     ,  0.      ,  0.      ],
#        [ 0.      ,  0.      , -1.002002, -2.002002],
#        [ 0.      ,  0.      , -1.      ,  0.      ]], dtype=float32))

# %% [markdown]
# ## 数据加载

# %% [markdown]
# ### 创建输出文件目录

# %%
os.makedirs(FLAGS.out_dir, exist_ok=True)
os.makedirs(os.path.join(FLAGS.out_dir, "mesh"), exist_ok=True)

# %% [markdown]
# ### 网格加载（Mesh Loading）

# %%
# 加载参考网格
ref_mesh = helper.load_mesh(FLAGS.ref_mesh, FLAGS.mtl_override)
print("参考网格包含 %d 三角面和 %d 顶点，平均边长为：%.4f" % (ref_mesh.t_pos_idx.shape[0], ref_mesh.v_pos.shape[0], regularizer.avg_edge_length(ref_mesh)))
# Out:
# 参考网格包含 2468 三角面和 1607 顶点，平均边长为：2.8440

# %%
# 加载基础网格
base_mesh = helper.load_mesh(FLAGS.base_mesh)
print("基础网格包含 %d 三角面和 %d 顶点，平均边长为：%.4f" % (base_mesh.t_pos_idx.shape[0], base_mesh.v_pos.shape[0], regularizer.avg_edge_length(base_mesh)))

def check_resolution(ref_mesh, texture_res):
    # 检测训练纹理的分辨率是否合规
    # Check if the training texture resolution is acceptable
    ref_texture_res = np.maximum(ref_mesh.material['kd'].getRes(), ref_mesh.material['ks'].getRes())
    if 'normal' in ref_mesh.material:
        ref_texture_res = np.maximum(ref_texture_res, ref_mesh.material['normal'].getRes())
    if texture_res[0] < ref_texture_res[0] or texture_res[1] < ref_texture_res[1]:
        print("---> 警告: 所选纹理分辨率小于参考网格纹理分辨率 [%d, %d] < [%d, %d]" % (texture_res[0], texture_res[1], ref_texture_res[0], ref_texture_res[1]))

check_resolution(ref_mesh, FLAGS.texture_res)

# 计算预期优化效果
t_reduction_rate = (1 - base_mesh.t_pos_idx.shape[0] / ref_mesh.t_pos_idx.shape[0]) * 100
v_reduction_rate = (1 - base_mesh.v_pos.shape[0] / ref_mesh.v_pos.shape[0]) * 100
print("预期减面率为: %.2f%%" % t_reduction_rate)
print("预期减点率为: %.2f%%" % v_reduction_rate)
# Out:
# 基础网格包含 3072 三角面和 1538 顶点，平均边长为：0.1346
# 预期减面率为: -24.47%
# 预期减点率为: 4.29%

# %%
ref_mesh.v_tex
# Out:
# tensor([[0.4721, 0.7125],
#         [0.4702, 0.7318],
#         [0.4725, 0.7329],
#         ...,
#         [0.5000, 0.0000],
#         [1.0000, 0.0000],
#         [0.5000, 0.0000]], device='cuda:0')

# %% [markdown]
# ### 网格归一化（Mesh Normalization）

# %%
normalized_base_mesh = mesh.unit_size(base_mesh)
normalized_ref_mesh = mesh.unit_size(ref_mesh)

# %% [markdown]
# ## 初始化训练网格的权重和变量

# %%
trainable_list = []
# 归一化基础网格顶点
v_pos_opt = normalized_base_mesh.v_pos.clone().detach().requires_grad_(True)
v_pos_opt
# Out:
# tensor([[-0.5956, -0.5956,  0.5956],
#         [-0.0921, -0.7230,  0.7230],
#         [-0.1827, -0.7143,  0.7143],
#         ...,
#         [-0.9572,  0.3001, -0.0988],
#         [-0.9786,  0.2018, -0.1003],
#         [-0.9914,  0.1014, -0.1014]], device='cuda:0', requires_grad=True)

# %% [markdown]
# #### 构建可训练的法线贴图，初始化为(0,0,1)，并确保法向量总处于正半球。
# Trainable normal map, initialize to (0,0,1) & make sure normals are always in positive hemisphere

# %%
if FLAGS.random_textures:
    normal_map_opt = texture.create_trainable(np.array([0, 0, 1]), FLAGS.texture_res, not FLAGS.custom_mip)
else:
    if 'normal' not in ref_mesh.material:
        normal_map_opt = texture.create_trainable(np.array([0, 0, 1]), FLAGS.texture_res, not FLAGS.custom_mip)
    else:
        normal_map_opt = texture.create_trainable(ref_mesh.material['normal'], FLAGS.texture_res, not FLAGS.custom_mip)

# %% [markdown]
# #### 创建可训练 Kd,Ks 反照率和高光纹理
# Setup Kd, Ks albedo and specular textures

# %%
if FLAGS.random_textures:
    if FLAGS.layers > 1:
        kd_map_opt = texture.create_trainable(np.random.uniform(size=FLAGS.texture_res + [4], low=0.0, high=1.0), FLAGS.texture_res, not FLAGS.custom_mip)
    else:
        kd_map_opt = texture.create_trainable(np.random.uniform(size=FLAGS.texture_res + [3], low=0.0, high=1.0), FLAGS.texture_res, not FLAGS.custom_mip)

    ksR = np.random.uniform(size=FLAGS.texture_res + [1], low=0.0, high=0.01)
    ksG = np.random.uniform(size=FLAGS.texture_res + [1], low=FLAGS.min_roughness, high=1.0)
    ksB = np.random.uniform(size=FLAGS.texture_res + [1], low=0.0, high=1.0)
    ks_map_opt = texture.create_trainable(np.concatenate((ksR, ksG, ksB), axis=2), FLAGS.texture_res, not FLAGS.custom_mip)
else:
    kd_map_opt = texture.create_trainable(ref_mesh.material['kd'], FLAGS.texture_res, not FLAGS.custom_mip)
    ks_map_opt = texture.create_trainable(ref_mesh.material['ks'], FLAGS.texture_res, not FLAGS.custom_mip)

# %%
print("反照率贴图：", kd_map_opt.data.shape)
# showImageTensor(kd_map_opt.data)
print("高光贴图：  ", ks_map_opt.data.shape)
# showImageTensor(ks_map_opt.data)
# Out:
# 反照率贴图： torch.Size([1, 1024, 1024, 3])
# 高光贴图：   torch.Size([1, 1024, 1024, 3])

# %% [markdown]
# #### 创建位移贴图
# Trainable displacement map

# %%
displacement_map_var = None
if FLAGS.subdivision > 0:
    displacement_map_var = torch.tensor(np.zeros(FLAGS.texture_res + [1], dtype=np.float32), dtype=torch.float32, device='cuda', requires_grad=True)

# %% [markdown]
# #### 根据配置信息组合训练参数
# Add trainable arguments according to config

# %%
if not 'position' in FLAGS.skip_train:
    trainable_list += [v_pos_opt]        
if not 'normal' in FLAGS.skip_train:
    trainable_list += normal_map_opt.getMips()
if not 'kd' in FLAGS.skip_train:
    trainable_list += kd_map_opt.getMips()
if not 'ks' in FLAGS.skip_train:
    trainable_list += ks_map_opt.getMips()
if not 'displacement' in FLAGS.skip_train and displacement_map_var is not None:
    trainable_list += [displacement_map_var]

# %% [markdown]
# ## 配置用于网格优化的材质
# Setup material for optimized mesh

# %%
opt_material = {
    'bsdf'   : ref_mesh.material['bsdf'],
    'kd'     : kd_map_opt,
    'ks'     : ks_map_opt,
    'normal' : normal_map_opt
}

# %% [markdown]
# ## 配置参考网格
# Setup reference mesh. Compute tangentspace and animate with skinning

# %%
render_ref_mesh = mesh.compute_tangents(ref_mesh)

# %%
render_ref_mesh.input.eval({}).v_pos
# Out:
# tensor([[  4.9622,   3.7216, -11.8371],
#         [  4.9622,   3.4953, -11.9000],
#         [  4.9622,   3.4953, -10.9000],
#         ...,
#         [ -7.0100,  10.6453,   8.9082],
#         [ -6.9100,   7.0953,   8.9333],
#         [ -6.9100,   7.0953,   5.3667]], device='cuda:0')

# %%
# Compute AABB of reference mesh. Used for centering during rendering TODO: Use pre frame AABB?
ref_mesh_aabb = mesh.aabb(render_ref_mesh.eval())

# %% [markdown]
# ## 配置基础网格及预计算
# Setup base mesh operation graph, precomputes topology etc.

# %%
# Create optimized mesh with trainable positions 
opt_base_mesh = Mesh(v_pos_opt, normalized_base_mesh.t_pos_idx, material=opt_material, base=normalized_base_mesh)

# Scale from [-1, 1] local coordinate space to match extents of the reference mesh
opt_base_mesh = mesh.align_with_reference(opt_base_mesh, ref_mesh)

# Compute smooth vertex normals
opt_base_mesh = mesh.auto_normals(opt_base_mesh)

# Set up tangent space
opt_base_mesh = mesh.compute_tangents(opt_base_mesh)

# Subdivide if we're doing displacement mapping
if FLAGS.subdivision > 0:
    # Subdivide & displace optimized mesh
    subdiv_opt_mesh = mesh.subdivide(opt_base_mesh, steps=FLAGS.subdivision)
    opt_detail_mesh = mesh.displace(subdiv_opt_mesh, displacement_map_var, FLAGS.displacement, keep_connectivity=True)
else:
    opt_detail_mesh = opt_base_mesh

# Laplace regularizer
if FLAGS.relative_laplacian:
    with torch.no_grad():
        orig_opt_base_mesh = opt_base_mesh.eval().clone()
    lap_loss_fn = regularizer.laplace_regularizer_const(opt_detail_mesh, orig_opt_base_mesh)
else:
    lap_loss_fn = regularizer.laplace_regularizer_const(opt_detail_mesh)

# %% [markdown]
# ## 配置优化器
# Setup torch optimizer

# %%
optimizer  = torch.optim.Adam(trainable_list, lr=FLAGS.learning_rate)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda x: max(0.0, 10**(-x*0.0002)))

# %% [markdown]
# ## 创建图像损失
# Image loss

# %%
image_loss_fn = helper.createLoss(FLAGS)

# Background color
if FLAGS.background == 'checker':
    background = torch.tensor(util.checkerboard(FLAGS.display_res, 8), dtype=torch.float32, device='cuda')
elif FLAGS.background == 'white':
    background = torch.ones((1, FLAGS.display_res, FLAGS.display_res, 3), dtype=torch.float32, device='cuda')
else:
    background = None

helper.showImageTensor(background)

# %% [markdown]
# ## 训练

# %%
def getRenderParams(flags):
    eye = np.array(flags.camera_eye)
    up  = np.array(flags.camera_up)
    at  = np.array([0,0,0])
    a_mv =  util.lookAt(eye, at, up)                                      # 模型视图（Model View）
    a_mvp = np.matmul(flags.proj_mtx, a_mv).astype(np.float32)[None, ...] # 模型视图投影（Model View Projection）
    a_lightpos = np.linalg.inv(a_mv)[None, :3, 3]
    a_campos = np.linalg.inv(a_mv)[None, :3, 3]
    return {'mvp' : a_mvp, 'lightpos' : a_lightpos, 'campos' : a_campos, 'resolution' : [FLAGS.display_res, FLAGS.display_res], 'time' : 0}

# %%
def renderScene(glctx, opt_base_mesh, opt_detail_mesh, render_ref_mesh, ref_mesh_aabb, background, displacement_map_var, FLAGS, mesh_scale, params):
    # Center meshes
    _opt_detail = mesh.center_by_reference(opt_detail_mesh.eval(params), ref_mesh_aabb, mesh_scale)
    _opt_ref    = mesh.center_by_reference(render_ref_mesh.eval(params), ref_mesh_aabb, mesh_scale)

    # Render
    if FLAGS.subdivision > 0:
        _opt_base   = mesh.center_by_reference(opt_base_mesh.eval(params), ref_mesh_aabb, mesh_scale)
        img_base = render.render_mesh(glctx, _opt_base, params['mvp'], params['campos'], params['lightpos'], FLAGS.light_power, FLAGS.display_res, 
            num_layers=FLAGS.layers, background=background, min_roughness=FLAGS.min_roughness)
        img_base = util.scale_img_nhwc(img_base, [FLAGS.display_res, FLAGS.display_res])

    img_opt = render.render_mesh(glctx, _opt_detail, params['mvp'], params['campos'],  params['lightpos'], FLAGS.light_power, FLAGS.display_res, 
        num_layers=FLAGS.layers, background=background, min_roughness=FLAGS.min_roughness)
    img_ref = render.render_mesh(glctx, _opt_ref, params['mvp'], params['campos'],  params['lightpos'], FLAGS.light_power, FLAGS.display_res, 
        num_layers=1, spp=FLAGS.spp, background=background, min_roughness=FLAGS.min_roughness)

    # Rescale
    img_opt  = util.scale_img_nhwc(img_opt,  [FLAGS.display_res, FLAGS.display_res])
    img_ref  = util.scale_img_nhwc(img_ref,  [FLAGS.display_res, FLAGS.display_res])

    if FLAGS.subdivision > 0:
        img_disp = torch.clamp(torch.abs(displacement_map_var[None, ...]), min=0.0, max=1.0).repeat(1,1,1,3)
        img_disp = util.scale_img_nhwc(img_disp, [FLAGS.display_res, FLAGS.display_res])
        result_image = torch.cat([img_base, img_opt, img_ref], axis=2)
    else:
        result_image = torch.cat([img_opt, img_ref], axis=2)
    return result_image

# %%
def displayAndSaveImage(glctx, opt_base_mesh, opt_detail_mesh, render_ref_mesh, ref_mesh_aabb, background, displacement_map_var, mesh_scale, img_cnt, it, FLAGS):
    display_image = FLAGS.display_interval and (it % FLAGS.display_interval == 0)
    save_image    = FLAGS.save_interval    and (it % FLAGS.save_interval == 0)

    params = getRenderParams(FLAGS)
    with torch.no_grad():
        result_image = renderScene(glctx, opt_base_mesh, opt_detail_mesh, render_ref_mesh, ref_mesh_aabb, background, displacement_map_var, FLAGS, mesh_scale, params)

    result_image[0] = util.tonemap_srgb(result_image[0])
    np_result_image = result_image[0].detach().cpu().numpy()
    
    if display_image:
        util.display_image(np_result_image, size=FLAGS.display_res, title='%d / %d' % (it, FLAGS.iter))
    if save_image:
        util.save_image(FLAGS.out_dir + '/' + ('img_%06d.png' % img_cnt), np_result_image)
        img_cnt = img_cnt+1
    return img_cnt

# %%
# ==============================================================================================
#  训练循环
#  Training Loop
# ==============================================================================================
img_cnt = 0        # 图片计数
ang = 0.0          #
img_loss_vec = []  # 图片损失向量集
lap_loss_vec = []  #
iter_dur_vec = []  #
mesh_scale=2.0

log_interval = 10

glctx = dr.RasterizeGLContext() # 可微渲染管线
for it in range(FLAGS.iter+1):
    
    # ==============================================================================================
    #  展示/保存输出。在最初执行用以获得初始网格数据。
    #  Display / save outputs. Do it before training so we get initial meshes
    # ==============================================================================================
    img_cnt = displayAndSaveImage(glctx, opt_base_mesh, opt_detail_mesh, render_ref_mesh, ref_mesh_aabb, 
                                  background, displacement_map_var, mesh_scale, img_cnt, it, FLAGS)    
    # ==============================================================================================
    #  训练初始化
    #  Initailize Training
    # ==============================================================================================
    iter_start_time = time.time()                                    # 记录迭代开始时间
    img_loss = torch.zeros([1], dtype=torch.float32, device='cuda')  # 初始化图像空间损失
    lap_loss = torch.zeros([1], dtype=torch.float32, device='cuda')  # 初始化laplace损失

    iter_res = FLAGS.train_res # 初始化分辨率
    iter_spp = FLAGS.spp       # 初始化单像素采样率
    if FLAGS.random_train_res:
        # 分辨率随机化
        # Random resolution, 16x16 -> train_res. Scale up sample count so we always land close to train_res*samples_per_pixel samples
        iter_res = np.random.randint(16, FLAGS.train_res+1)
        iter_spp = FLAGS.spp * (FLAGS.train_res // iter_res)
 
    mvp      = np.zeros((FLAGS.batch, 4,4), dtype=np.float32) # 模型视图投影矩阵（Model View Projection）
    campos   = np.zeros((FLAGS.batch, 3),   dtype=np.float32) # 相机位置（Camera Position）
    lightpos = np.zeros((FLAGS.batch, 3),   dtype=np.float32) # 光源位置（Light Position）

    # ==============================================================================================
    #  构建用于minibatching的变换栈
    #  Build transform stack for minibatching
    # ==============================================================================================
    for b in range(FLAGS.batch):
        # 随机旋转/平移矩阵用于优化
        # Random rotation/translation matrix for optimization.
        r_rot      = util.random_rotation_translation(0.25)                 # 随机渲染矩阵
        r_mv       = np.matmul(util.translate(0, 0, -FLAGS.radius), r_rot)  # 随机模型视图
        mvp[b]     = np.matmul(FLAGS.proj_mtx, r_mv).astype(np.float32)     # 随机模型视图投影
        campos[b]  = np.linalg.inv(r_mv)[:3, 3]                             # 随机相机位置
        lightpos[b] = util.cosine_sample(campos[b])*FLAGS.radius            # 随机光源位置
    params = {'mvp' : mvp, 'lightpos' : lightpos, 'campos' : campos, 'resolution' : [iter_res, iter_res], 'time' : 0}
    # 随机背景颜色
    # Random bg color
    randomBgColor = torch.rand(FLAGS.batch, iter_res, iter_res, 3, dtype=torch.float32, device='cuda')
    # ==============================================================================================
    #  居中对齐所有网格
    #  Evaluate all mesh ops (may change when positions are modified etc) and center/align meshes
    # ==============================================================================================
    _opt_ref  = mesh.center_by_reference(render_ref_mesh.eval(params), ref_mesh_aabb, mesh_scale)
    _opt_detail = mesh.center_by_reference(opt_detail_mesh.eval(params), ref_mesh_aabb, mesh_scale)
    # ==============================================================================================
    #  渲染参考网格
    #  Render reference mesh
    # ==============================================================================================
    with torch.no_grad():
        color_ref = render.render_mesh(glctx, _opt_ref, mvp, campos, lightpos, FLAGS.light_power, iter_res, spp=iter_spp, num_layers=1, 
                                       background=randomBgColor, min_roughness=FLAGS.min_roughness)
    # ==============================================================================================
    #  渲染训练网格
    #  Render the trainable mesh
    # ==============================================================================================
    color_opt = render.render_mesh(glctx, _opt_detail, mvp, campos, lightpos, FLAGS.light_power, iter_res, spp=iter_spp, num_layers=FLAGS.layers, 
                                   msaa=True , background=randomBgColor, min_roughness=FLAGS.min_roughness)
    # ==============================================================================================
    #  损失计算
    #  Compute loss
    # ==============================================================================================
    # 计算图像空间损失
    img_loss = image_loss_fn(color_opt, color_ref)
    # 计算laplace损失
    lap_loss = lap_loss_fn.eval(params)

    # Debug, store every training iteration
    # result_image = torch.cat([color_opt, color_ref], axis=2)
    # np_result_image = result_image[0].detach().cpu().numpy()
    # util.save_image(out_dir + '/' + ('train_%06d.png' % it), np_result_image)

    # 记录损失
    img_loss_vec.append(img_loss.item())
    lap_loss_vec.append(lap_loss.item())

    # Schedule for laplacian loss weight
    if it == 0:
        if FLAGS.laplacian_factor is not None:
            lap_fac = FLAGS.laplacian_factor
        else:
            ratio = 0.1 / lap_loss.item() # Hack that assumes RMSE ~= 0.1
            lap_fac = ratio * 0.25
        min_lap_fac = lap_fac * 0.02
    else:
        lap_fac = (lap_fac - min_lap_fac) * 10**(-it*0.000001) + min_lap_fac

    # Compute total aggregate loss
    total_loss = img_loss + lap_loss * lap_fac

    # ==============================================================================================
    #  反向传播（Backpropagate）
    # ==============================================================================================
    optimizer.zero_grad()
    total_loss.backward()
    optimizer.step()
    scheduler.step()
    # ==============================================================================================
    #  将训练参数裁剪至合理区间（Clamp trainables to reasonable range）
    # ==============================================================================================
    normal_map_opt.clamp_(min=-1, max=1)
    kd_map_opt.clamp_(min=0, max=1)
    ks_map_opt.clamp_rgb_(minR=0, maxR=1, minG=FLAGS.min_roughness, maxG=1.0, minB=0.0, maxB=1.0)
    iter_dur_vec.append(time.time() - iter_start_time)
    # ==============================================================================================
    #  保存日志（Log & save outputs）
    # ==============================================================================================
    if log_interval and (it % log_interval == 0):
        # with torch.no_grad():
            #helper.showBatchImageTensor(color_ref, FLAGS.batch)
            #helper.showBatchImageTensor(color_opt, FLAGS.batch)
        
        img_loss_avg = np.mean(np.asarray(img_loss_vec[-log_interval:]))
        lap_loss_avg = np.mean(np.asarray(lap_loss_vec[-log_interval:]))
        iter_dur_avg = np.mean(np.asarray(iter_dur_vec[-log_interval:]))
        remaining_time = (FLAGS.iter-it)*iter_dur_avg
        print("iter=%5d, img_loss=%.6f, lap_loss=%.6f, lr=%.5f, time=%.1f ms, rem=%s" % 
            (it, img_loss_avg, lap_loss_avg*lap_fac, optimizer.param_groups[0]['lr'], iter_dur_avg*1000, util.time_to_text(remaining_time)))

# Save final mesh to file
obj.write_obj(os.path.join(FLAGS.out_dir, "mesh/"), opt_base_mesh.eval())
# Out:
# iter=    0, img_loss=0.087380, lap_loss=0.025000, lr=0.01000, time=49.0 ms, rem=8.17 m
# iter=   10, img_loss=0.081268, lap_loss=0.017888, lr=0.00995, time=21.3 ms, rem=3.54 m
# iter=   20, img_loss=0.078621, lap_loss=0.010128, lr=0.00990, time=20.5 ms, rem=3.41 m
# iter=   30, img_loss=0.072873, lap_loss=0.007717, lr=0.00986, time=17.3 ms, rem=2.88 m
# iter=   40, img_loss=0.077382, lap_loss=0.006814, lr=0.00981, time=14.1 ms, rem=2.34 m
# iter=   50, img_loss=0.067421, lap_loss=0.006698, lr=0.00977, time=13.8 ms, rem=2.28 m
# iter=   60, img_loss=0.066905, lap_loss=0.006456, lr=0.00972, time=15.6 ms, rem=2.58 m
# iter=   70, img_loss=0.064967, lap_loss=0.006367, lr=0.00968, time=16.1 ms, rem=2.66 m
# iter=   80, img_loss=0.057566, lap_loss=0.006294, lr=0.00963, time=15.1 ms, rem=2.49 m
# iter=   90, img_loss=0.057096, lap_loss=0.006227, lr=0.00959, time=14.4 ms, rem=2.38 m
# iter=  100, img_loss=0.053681, lap_loss=0.006544, lr=0.00955, time=13.8 ms, rem=2.27 m
# iter=  110, img_loss=0.052855, lap_loss=0.006533, lr=0.00950, time=13.8 ms, rem=2.27 m
# iter=  120, img_loss=0.050679, lap_loss=0.006603, lr=0.00946, time=14.7 ms, rem=2.41 m
# iter=  130, img_loss=0.046578, lap_loss=0.006647, lr=0.00941, time=14.4 ms, rem=2.36 m
# iter=  140, img_loss=0.043709, lap_loss=0.006828, lr=0.00937, time=13.9 ms, rem=2.28 m
# iter=  150, img_loss=0.043428, lap_loss=0.006919, lr=0.00933, time=14.3 ms, rem=2.35 m
# iter=  160, img_loss=0.040123, lap_loss=0.007099, lr=0.00929, time=15.1 ms, rem=2.47 m
# iter=  170, img_loss=0.039942, lap_loss=0.007134, lr=0.00924, time=16.1 ms, rem=2.63 m
# iter=  180, img_loss=0.037568, lap_loss=0.007116, lr=0.00920, time=15.4 ms, rem=2.52 m
# iter=  190, img_loss=0.038716, lap_loss=0.007148, lr=0.00916, time=16.3 ms, rem=2.67 m
# iter=  200, img_loss=0.035929, lap_loss=0.007203, lr=0.00912, time=16.1 ms, rem=2.63 m
# iter=  210, img_loss=0.033309, lap_loss=0.007164, lr=0.00907, time=15.0 ms, rem=2.44 m
# iter=  220, img_loss=0.032119, lap_loss=0.007329, lr=0.00903, time=14.1 ms, rem=2.30 m
# iter=  230, img_loss=0.031766, lap_loss=0.007201, lr=0.00899, time=14.2 ms, rem=2.31 m
# iter=  240, img_loss=0.030070, lap_loss=0.006991, lr=0.00895, time=14.7 ms, rem=2.40 m
# iter=  250, img_loss=0.029603, lap_loss=0.006939, lr=0.00891, time=15.4 ms, rem=2.50 m
# iter=  260, img_loss=0.027664, lap_loss=0.007129, lr=0.00887, time=14.9 ms, rem=2.42 m
# iter=  270, img_loss=0.035466, lap_loss=0.007296, lr=0.00883, time=15.3 ms, rem=2.48 m
# iter=  280, img_loss=0.029045, lap_loss=0.007249, lr=0.00879, time=14.9 ms, rem=2.42 m
# iter=  290, img_loss=0.030658, lap_loss=0.007226, lr=0.00875, time=14.9 ms, rem=2.41 m
# iter=  300, img_loss=0.030077, lap_loss=0.007088, lr=0.00871, time=14.2 ms, rem=2.29 m
# iter=  310, img_loss=0.028646, lap_loss=0.007052, lr=0.00867, time=17.0 ms, rem=2.75 m
# iter=  320, img_loss=0.029184, lap_loss=0.007062, lr=0.00863, time=15.4 ms, rem=2.48 m
# iter=  330, img_loss=0.025335, lap_loss=0.006911, lr=0.00859, time=16.0 ms, rem=2.57 m
# iter=  340, img_loss=0.028348, lap_loss=0.006846, lr=0.00855, time=13.8 ms, rem=2.23 m
# iter=  350, img_loss=0.026934, lap_loss=0.006911, lr=0.00851, time=13.8 ms, rem=2.22 m
# iter=  360, img_loss=0.028022, lap_loss=0.007021, lr=0.00847, time=13.8 ms, rem=2.22 m
# iter=  370, img_loss=0.027523, lap_loss=0.006923, lr=0.00843, time=14.2 ms, rem=2.28 m
# iter=  380, img_loss=0.029959, lap_loss=0.006887, lr=0.00839, time=14.0 ms, rem=2.25 m
# iter=  390, img_loss=0.026900, lap_loss=0.006857, lr=0.00835, time=15.3 ms, rem=2.45 m
# iter=  400, img_loss=0.025769, lap_loss=0.006706, lr=0.00831, time=14.9 ms, rem=2.38 m
# iter=  410, img_loss=0.024375, lap_loss=0.006587, lr=0.00828, time=15.2 ms, rem=2.43 m
# iter=  420, img_loss=0.026880, lap_loss=0.006594, lr=0.00824, time=13.7 ms, rem=2.19 m
# iter=  430, img_loss=0.024229, lap_loss=0.006655, lr=0.00820, time=14.3 ms, rem=2.28 m
# iter=  440, img_loss=0.025825, lap_loss=0.006602, lr=0.00816, time=14.2 ms, rem=2.26 m
# iter=  450, img_loss=0.026620, lap_loss=0.006392, lr=0.00812, time=14.2 ms, rem=2.26 m
# iter=  460, img_loss=0.027026, lap_loss=0.006415, lr=0.00809, time=13.9 ms, rem=2.21 m
# iter=  470, img_loss=0.026960, lap_loss=0.006351, lr=0.00805, time=13.9 ms, rem=2.21 m
# iter=  480, img_loss=0.027538, lap_loss=0.006221, lr=0.00801, time=14.3 ms, rem=2.26 m
# iter=  490, img_loss=0.024441, lap_loss=0.006360, lr=0.00798, time=13.6 ms, rem=2.15 m
# iter=  500, img_loss=0.025566, lap_loss=0.006161, lr=0.00794, time=14.3 ms, rem=2.26 m
# iter=  510, img_loss=0.026809, lap_loss=0.006067, lr=0.00790, time=14.4 ms, rem=2.28 m
# iter=  520, img_loss=0.024722, lap_loss=0.005962, lr=0.00787, time=15.2 ms, rem=2.40 m
# iter=  530, img_loss=0.025107, lap_loss=0.006096, lr=0.00783, time=14.5 ms, rem=2.29 m
# iter=  540, img_loss=0.025772, lap_loss=0.006071, lr=0.00779, time=15.1 ms, rem=2.38 m
# iter=  550, img_loss=0.027696, lap_loss=0.005942, lr=0.00776, time=18.1 ms, rem=2.85 m
# iter=  560, img_loss=0.025505, lap_loss=0.005950, lr=0.00772, time=17.2 ms, rem=2.71 m
# iter=  570, img_loss=0.024128, lap_loss=0.005612, lr=0.00769, time=17.6 ms, rem=2.77 m
# iter=  580, img_loss=0.025118, lap_loss=0.005740, lr=0.00765, time=20.0 ms, rem=3.14 m
# iter=  590, img_loss=0.029175, lap_loss=0.005714, lr=0.00762, time=18.8 ms, rem=2.94 m
# iter=  600, img_loss=0.025789, lap_loss=0.005643, lr=0.00758, time=13.9 ms, rem=2.18 m
# iter=  610, img_loss=0.025779, lap_loss=0.005559, lr=0.00755, time=13.8 ms, rem=2.16 m
# iter=  620, img_loss=0.023323, lap_loss=0.005304, lr=0.00751, time=14.7 ms, rem=2.30 m
# iter=  630, img_loss=0.029047, lap_loss=0.005233, lr=0.00748, time=14.0 ms, rem=2.19 m
# iter=  640, img_loss=0.022128, lap_loss=0.005157, lr=0.00744, time=14.6 ms, rem=2.27 m
# iter=  650, img_loss=0.024750, lap_loss=0.005190, lr=0.00741, time=14.0 ms, rem=2.17 m
# iter=  660, img_loss=0.024446, lap_loss=0.005171, lr=0.00738, time=13.4 ms, rem=2.09 m
# iter=  670, img_loss=0.027043, lap_loss=0.005382, lr=0.00734, time=13.6 ms, rem=2.12 m
# iter=  680, img_loss=0.025025, lap_loss=0.005218, lr=0.00731, time=13.9 ms, rem=2.15 m
# iter=  690, img_loss=0.025953, lap_loss=0.005238, lr=0.00727, time=14.4 ms, rem=2.23 m
# iter=  700, img_loss=0.024227, lap_loss=0.005002, lr=0.00724, time=14.2 ms, rem=2.20 m
# iter=  710, img_loss=0.023606, lap_loss=0.004777, lr=0.00721, time=13.9 ms, rem=2.15 m
# iter=  720, img_loss=0.023049, lap_loss=0.004707, lr=0.00717, time=13.7 ms, rem=2.12 m
# iter=  730, img_loss=0.024638, lap_loss=0.004759, lr=0.00714, time=13.9 ms, rem=2.15 m
# iter=  740, img_loss=0.024437, lap_loss=0.004719, lr=0.00711, time=14.1 ms, rem=2.17 m
# iter=  750, img_loss=0.021267, lap_loss=0.004648, lr=0.00708, time=14.3 ms, rem=2.21 m
# iter=  760, img_loss=0.022851, lap_loss=0.004655, lr=0.00704, time=14.0 ms, rem=2.15 m
# iter=  770, img_loss=0.021506, lap_loss=0.004635, lr=0.00701, time=13.5 ms, rem=2.07 m
# iter=  780, img_loss=0.022493, lap_loss=0.004427, lr=0.00698, time=14.5 ms, rem=2.23 m
# iter=  790, img_loss=0.023661, lap_loss=0.004429, lr=0.00695, time=13.6 ms, rem=2.08 m
# iter=  800, img_loss=0.022846, lap_loss=0.004389, lr=0.00692, time=14.0 ms, rem=2.15 m
# iter=  810, img_loss=0.022274, lap_loss=0.004349, lr=0.00688, time=14.7 ms, rem=2.25 m
# iter=  820, img_loss=0.023388, lap_loss=0.004153, lr=0.00685, time=17.4 ms, rem=2.66 m
# iter=  830, img_loss=0.023625, lap_loss=0.004205, lr=0.00682, time=15.9 ms, rem=2.44 m
# iter=  840, img_loss=0.024856, lap_loss=0.004183, lr=0.00679, time=15.3 ms, rem=2.34 m
# iter=  850, img_loss=0.021160, lap_loss=0.004057, lr=0.00676, time=14.3 ms, rem=2.18 m
# iter=  860, img_loss=0.022384, lap_loss=0.003956, lr=0.00673, time=13.5 ms, rem=2.05 m
# iter=  870, img_loss=0.019372, lap_loss=0.003888, lr=0.00670, time=16.1 ms, rem=2.45 m
# iter=  880, img_loss=0.022956, lap_loss=0.003889, lr=0.00666, time=17.0 ms, rem=2.59 m
# iter=  890, img_loss=0.023033, lap_loss=0.003849, lr=0.00663, time=15.7 ms, rem=2.38 m
# iter=  900, img_loss=0.025252, lap_loss=0.003755, lr=0.00660, time=13.9 ms, rem=2.11 m
# iter=  910, img_loss=0.022314, lap_loss=0.003898, lr=0.00657, time=14.1 ms, rem=2.13 m
# iter=  920, img_loss=0.020555, lap_loss=0.003715, lr=0.00654, time=13.3 ms, rem=2.01 m
# iter=  930, img_loss=0.021922, lap_loss=0.003599, lr=0.00651, time=14.9 ms, rem=2.25 m
# iter=  940, img_loss=0.022820, lap_loss=0.003513, lr=0.00648, time=14.1 ms, rem=2.13 m
# iter=  950, img_loss=0.022015, lap_loss=0.003530, lr=0.00645, time=13.7 ms, rem=2.07 m
# iter=  960, img_loss=0.022460, lap_loss=0.003355, lr=0.00642, time=13.9 ms, rem=2.09 m
# iter=  970, img_loss=0.022006, lap_loss=0.003409, lr=0.00639, time=14.0 ms, rem=2.10 m
# iter=  980, img_loss=0.024144, lap_loss=0.003402, lr=0.00637, time=13.7 ms, rem=2.06 m
# iter=  990, img_loss=0.023187, lap_loss=0.003396, lr=0.00634, time=13.7 ms, rem=2.06 m
# iter= 1000, img_loss=0.020228, lap_loss=0.003334, lr=0.00631, time=13.9 ms, rem=2.08 m
# iter= 1010, img_loss=0.021052, lap_loss=0.003252, lr=0.00628, time=14.0 ms, rem=2.10 m
# iter= 1020, img_loss=0.022114, lap_loss=0.003238, lr=0.00625, time=13.5 ms, rem=2.02 m
# iter= 1030, img_loss=0.021454, lap_loss=0.003196, lr=0.00622, time=13.8 ms, rem=2.06 m
# iter= 1040, img_loss=0.023278, lap_loss=0.003163, lr=0.00619, time=13.3 ms, rem=1.99 m
# iter= 1050, img_loss=0.020951, lap_loss=0.003031, lr=0.00616, time=13.5 ms, rem=2.01 m
# iter= 1060, img_loss=0.021457, lap_loss=0.002915, lr=0.00613, time=13.6 ms, rem=2.03 m
# iter= 1070, img_loss=0.021841, lap_loss=0.002917, lr=0.00611, time=14.1 ms, rem=2.10 m
# iter= 1080, img_loss=0.016644, lap_loss=0.002821, lr=0.00608, time=13.5 ms, rem=2.01 m
# iter= 1090, img_loss=0.018574, lap_loss=0.002735, lr=0.00605, time=13.8 ms, rem=2.05 m
# iter= 1100, img_loss=0.021490, lap_loss=0.002741, lr=0.00602, time=13.7 ms, rem=2.03 m
# iter= 1110, img_loss=0.021824, lap_loss=0.002686, lr=0.00600, time=13.6 ms, rem=2.01 m
# iter= 1120, img_loss=0.021507, lap_loss=0.002562, lr=0.00597, time=13.5 ms, rem=2.00 m
# iter= 1130, img_loss=0.017774, lap_loss=0.002523, lr=0.00594, time=13.8 ms, rem=2.03 m
# iter= 1140, img_loss=0.019756, lap_loss=0.002466, lr=0.00591, time=15.3 ms, rem=2.27 m
# iter= 1150, img_loss=0.019780, lap_loss=0.002476, lr=0.00589, time=15.4 ms, rem=2.27 m
# iter= 1160, img_loss=0.020977, lap_loss=0.002473, lr=0.00586, time=15.2 ms, rem=2.24 m
# iter= 1170, img_loss=0.020213, lap_loss=0.002528, lr=0.00583, time=14.7 ms, rem=2.16 m
# iter= 1180, img_loss=0.022318, lap_loss=0.002405, lr=0.00580, time=13.4 ms, rem=1.97 m
# iter= 1190, img_loss=0.021010, lap_loss=0.002386, lr=0.00578, time=13.7 ms, rem=2.02 m
# iter= 1200, img_loss=0.019123, lap_loss=0.002346, lr=0.00575, time=13.8 ms, rem=2.02 m
# iter= 1210, img_loss=0.022027, lap_loss=0.002314, lr=0.00573, time=14.2 ms, rem=2.08 m
# iter= 1220, img_loss=0.020512, lap_loss=0.002239, lr=0.00570, time=14.0 ms, rem=2.05 m
# iter= 1230, img_loss=0.021514, lap_loss=0.002258, lr=0.00567, time=14.3 ms, rem=2.09 m
# iter= 1240, img_loss=0.021620, lap_loss=0.002222, lr=0.00565, time=14.2 ms, rem=2.07 m
# iter= 1250, img_loss=0.019448, lap_loss=0.002259, lr=0.00562, time=13.4 ms, rem=1.95 m
# iter= 1260, img_loss=0.021047, lap_loss=0.002156, lr=0.00559, time=13.9 ms, rem=2.02 m
# iter= 1270, img_loss=0.019203, lap_loss=0.002200, lr=0.00557, time=13.7 ms, rem=1.99 m
# iter= 1280, img_loss=0.021602, lap_loss=0.002149, lr=0.00554, time=13.7 ms, rem=1.99 m
# iter= 1290, img_loss=0.019350, lap_loss=0.002063, lr=0.00552, time=13.3 ms, rem=1.93 m
# iter= 1300, img_loss=0.020510, lap_loss=0.002069, lr=0.00549, time=13.2 ms, rem=1.91 m
# iter= 1310, img_loss=0.017387, lap_loss=0.002004, lr=0.00547, time=13.7 ms, rem=1.98 m
# iter= 1320, img_loss=0.022602, lap_loss=0.001907, lr=0.00544, time=14.0 ms, rem=2.02 m
# iter= 1330, img_loss=0.019342, lap_loss=0.001987, lr=0.00542, time=13.8 ms, rem=1.99 m
# iter= 1340, img_loss=0.021142, lap_loss=0.001970, lr=0.00539, time=14.1 ms, rem=2.03 m
# iter= 1350, img_loss=0.019744, lap_loss=0.001977, lr=0.00537, time=13.4 ms, rem=1.94 m
# iter= 1360, img_loss=0.021250, lap_loss=0.001958, lr=0.00534, time=13.9 ms, rem=2.00 m
# iter= 1370, img_loss=0.018255, lap_loss=0.001875, lr=0.00532, time=13.7 ms, rem=1.97 m
# iter= 1380, img_loss=0.019970, lap_loss=0.001797, lr=0.00529, time=15.1 ms, rem=2.16 m
# iter= 1390, img_loss=0.020376, lap_loss=0.001709, lr=0.00527, time=16.7 ms, rem=2.39 m
# iter= 1400, img_loss=0.019942, lap_loss=0.001699, lr=0.00525, time=15.2 ms, rem=2.18 m
# iter= 1410, img_loss=0.018325, lap_loss=0.001743, lr=0.00522, time=14.5 ms, rem=2.07 m
# iter= 1420, img_loss=0.018279, lap_loss=0.001711, lr=0.00520, time=16.1 ms, rem=2.30 m
# iter= 1430, img_loss=0.020657, lap_loss=0.001708, lr=0.00517, time=15.5 ms, rem=2.21 m
# iter= 1440, img_loss=0.020713, lap_loss=0.001671, lr=0.00515, time=13.6 ms, rem=1.93 m
# iter= 1450, img_loss=0.017627, lap_loss=0.001657, lr=0.00513, time=14.0 ms, rem=2.00 m
# iter= 1460, img_loss=0.021738, lap_loss=0.001646, lr=0.00510, time=15.7 ms, rem=2.23 m
# iter= 1470, img_loss=0.021275, lap_loss=0.001576, lr=0.00508, time=15.7 ms, rem=2.23 m
# iter= 1480, img_loss=0.020170, lap_loss=0.001526, lr=0.00506, time=14.6 ms, rem=2.07 m
# iter= 1490, img_loss=0.018817, lap_loss=0.001514, lr=0.00503, time=13.6 ms, rem=1.93 m
# iter= 1500, img_loss=0.018218, lap_loss=0.001417, lr=0.00501, time=13.8 ms, rem=1.96 m
# iter= 1510, img_loss=0.016084, lap_loss=0.001476, lr=0.00499, time=14.1 ms, rem=1.99 m
# iter= 1520, img_loss=0.020250, lap_loss=0.001584, lr=0.00496, time=13.6 ms, rem=1.92 m
# iter= 1530, img_loss=0.016641, lap_loss=0.001582, lr=0.00494, time=14.0 ms, rem=1.97 m
# iter= 1540, img_loss=0.017975, lap_loss=0.001502, lr=0.00492, time=14.4 ms, rem=2.03 m
# iter= 1550, img_loss=0.015735, lap_loss=0.001413, lr=0.00490, time=16.4 ms, rem=2.31 m
# iter= 1560, img_loss=0.017751, lap_loss=0.001446, lr=0.00487, time=15.7 ms, rem=2.21 m
# iter= 1570, img_loss=0.021078, lap_loss=0.001587, lr=0.00485, time=14.7 ms, rem=2.07 m
# iter= 1580, img_loss=0.016877, lap_loss=0.001647, lr=0.00483, time=15.1 ms, rem=2.12 m
# iter= 1590, img_loss=0.018161, lap_loss=0.001527, lr=0.00481, time=15.5 ms, rem=2.17 m
# iter= 1600, img_loss=0.018951, lap_loss=0.001410, lr=0.00478, time=16.7 ms, rem=2.34 m
# iter= 1610, img_loss=0.017960, lap_loss=0.001379, lr=0.00476, time=15.5 ms, rem=2.17 m
# iter= 1620, img_loss=0.018809, lap_loss=0.001350, lr=0.00474, time=15.7 ms, rem=2.20 m
# iter= 1630, img_loss=0.016421, lap_loss=0.001297, lr=0.00472, time=16.0 ms, rem=2.24 m
# iter= 1640, img_loss=0.018082, lap_loss=0.001260, lr=0.00470, time=15.0 ms, rem=2.09 m
# iter= 1650, img_loss=0.020852, lap_loss=0.001313, lr=0.00468, time=14.0 ms, rem=1.95 m
# iter= 1660, img_loss=0.018173, lap_loss=0.001304, lr=0.00465, time=14.0 ms, rem=1.94 m
# iter= 1670, img_loss=0.017198, lap_loss=0.001235, lr=0.00463, time=13.7 ms, rem=1.90 m
# iter= 1680, img_loss=0.016282, lap_loss=0.001251, lr=0.00461, time=14.6 ms, rem=2.02 m
# iter= 1690, img_loss=0.018658, lap_loss=0.001252, lr=0.00459, time=16.8 ms, rem=2.33 m
# iter= 1700, img_loss=0.017111, lap_loss=0.001224, lr=0.00457, time=15.6 ms, rem=2.16 m
# iter= 1710, img_loss=0.021682, lap_loss=0.001264, lr=0.00455, time=15.2 ms, rem=2.10 m
# iter= 1720, img_loss=0.020027, lap_loss=0.001187, lr=0.00453, time=13.8 ms, rem=1.90 m
# iter= 1730, img_loss=0.017436, lap_loss=0.001165, lr=0.00451, time=14.6 ms, rem=2.01 m
# iter= 1740, img_loss=0.015223, lap_loss=0.001181, lr=0.00449, time=14.1 ms, rem=1.94 m
# iter= 1750, img_loss=0.017023, lap_loss=0.001201, lr=0.00446, time=13.4 ms, rem=1.84 m
# iter= 1760, img_loss=0.017636, lap_loss=0.001166, lr=0.00444, time=14.1 ms, rem=1.93 m
# iter= 1770, img_loss=0.018994, lap_loss=0.001175, lr=0.00442, time=13.6 ms, rem=1.87 m
# iter= 1780, img_loss=0.015244, lap_loss=0.001157, lr=0.00440, time=14.2 ms, rem=1.94 m
# iter= 1790, img_loss=0.019461, lap_loss=0.001131, lr=0.00438, time=14.5 ms, rem=1.98 m
# iter= 1800, img_loss=0.017890, lap_loss=0.001119, lr=0.00436, time=14.8 ms, rem=2.03 m
# iter= 1810, img_loss=0.016459, lap_loss=0.001115, lr=0.00434, time=15.3 ms, rem=2.09 m
# iter= 1820, img_loss=0.017903, lap_loss=0.001111, lr=0.00432, time=16.9 ms, rem=2.30 m
# iter= 1830, img_loss=0.018392, lap_loss=0.001099, lr=0.00430, time=14.4 ms, rem=1.96 m
# iter= 1840, img_loss=0.019804, lap_loss=0.001110, lr=0.00428, time=14.1 ms, rem=1.91 m
# iter= 1850, img_loss=0.016607, lap_loss=0.001089, lr=0.00426, time=13.8 ms, rem=1.87 m
# iter= 1860, img_loss=0.017362, lap_loss=0.001054, lr=0.00424, time=14.1 ms, rem=1.91 m
# iter= 1870, img_loss=0.016539, lap_loss=0.001024, lr=0.00422, time=13.9 ms, rem=1.88 m
# iter= 1880, img_loss=0.018570, lap_loss=0.001069, lr=0.00421, time=13.9 ms, rem=1.89 m
# iter= 1890, img_loss=0.017129, lap_loss=0.001061, lr=0.00419, time=13.8 ms, rem=1.86 m
# iter= 1900, img_loss=0.016913, lap_loss=0.001032, lr=0.00417, time=14.0 ms, rem=1.89 m
# iter= 1910, img_loss=0.015866, lap_loss=0.001085, lr=0.00415, time=13.5 ms, rem=1.82 m
# iter= 1920, img_loss=0.016475, lap_loss=0.001081, lr=0.00413, time=13.8 ms, rem=1.86 m
# iter= 1930, img_loss=0.016731, lap_loss=0.001053, lr=0.00411, time=14.0 ms, rem=1.88 m
# iter= 1940, img_loss=0.017571, lap_loss=0.001061, lr=0.00409, time=13.7 ms, rem=1.84 m
# iter= 1950, img_loss=0.015277, lap_loss=0.001033, lr=0.00407, time=14.5 ms, rem=1.95 m
# iter= 1960, img_loss=0.017798, lap_loss=0.000994, lr=0.00405, time=13.8 ms, rem=1.85 m
# iter= 1970, img_loss=0.019028, lap_loss=0.000988, lr=0.00403, time=13.8 ms, rem=1.85 m
# iter= 1980, img_loss=0.015741, lap_loss=0.000974, lr=0.00402, time=13.5 ms, rem=1.80 m
# iter= 1990, img_loss=0.015062, lap_loss=0.000972, lr=0.00400, time=14.2 ms, rem=1.90 m
# iter= 2000, img_loss=0.018078, lap_loss=0.000987, lr=0.00398, time=15.1 ms, rem=2.01 m
# iter= 2010, img_loss=0.015378, lap_loss=0.000987, lr=0.00396, time=14.2 ms, rem=1.89 m
# iter= 2020, img_loss=0.017960, lap_loss=0.000968, lr=0.00394, time=14.9 ms, rem=1.98 m
# iter= 2030, img_loss=0.019589, lap_loss=0.001000, lr=0.00392, time=14.2 ms, rem=1.89 m
# iter= 2040, img_loss=0.016472, lap_loss=0.001032, lr=0.00391, time=13.4 ms, rem=1.78 m
# iter= 2050, img_loss=0.017029, lap_loss=0.001017, lr=0.00389, time=13.5 ms, rem=1.79 m
# iter= 2060, img_loss=0.017785, lap_loss=0.001059, lr=0.00387, time=13.9 ms, rem=1.84 m
# iter= 2070, img_loss=0.016884, lap_loss=0.001116, lr=0.00385, time=13.7 ms, rem=1.81 m
# iter= 2080, img_loss=0.016797, lap_loss=0.001076, lr=0.00384, time=13.4 ms, rem=1.77 m
# iter= 2090, img_loss=0.018483, lap_loss=0.001019, lr=0.00382, time=13.8 ms, rem=1.82 m
# iter= 2100, img_loss=0.014854, lap_loss=0.000983, lr=0.00380, time=14.0 ms, rem=1.84 m
# iter= 2110, img_loss=0.017702, lap_loss=0.000969, lr=0.00378, time=14.3 ms, rem=1.88 m
# iter= 2120, img_loss=0.015770, lap_loss=0.000989, lr=0.00377, time=15.0 ms, rem=1.98 m
# iter= 2130, img_loss=0.016362, lap_loss=0.000996, lr=0.00375, time=15.8 ms, rem=2.08 m
# iter= 2140, img_loss=0.016514, lap_loss=0.000995, lr=0.00373, time=18.6 ms, rem=2.44 m
# iter= 2150, img_loss=0.016641, lap_loss=0.001029, lr=0.00371, time=15.7 ms, rem=2.06 m
# iter= 2160, img_loss=0.015431, lap_loss=0.001028, lr=0.00370, time=17.0 ms, rem=2.22 m
# iter= 2170, img_loss=0.015318, lap_loss=0.000999, lr=0.00368, time=14.0 ms, rem=1.83 m
# iter= 2180, img_loss=0.017595, lap_loss=0.000971, lr=0.00366, time=13.8 ms, rem=1.79 m
# iter= 2190, img_loss=0.017023, lap_loss=0.000959, lr=0.00365, time=13.4 ms, rem=1.74 m
# iter= 2200, img_loss=0.016156, lap_loss=0.000975, lr=0.00363, time=14.0 ms, rem=1.82 m
# iter= 2210, img_loss=0.017537, lap_loss=0.000972, lr=0.00361, time=14.0 ms, rem=1.81 m
# iter= 2220, img_loss=0.017868, lap_loss=0.000971, lr=0.00360, time=13.6 ms, rem=1.76 m
# iter= 2230, img_loss=0.018063, lap_loss=0.000992, lr=0.00358, time=14.0 ms, rem=1.82 m
# iter= 2240, img_loss=0.017284, lap_loss=0.000991, lr=0.00356, time=13.9 ms, rem=1.79 m
# iter= 2250, img_loss=0.016309, lap_loss=0.000955, lr=0.00355, time=13.8 ms, rem=1.78 m
# iter= 2260, img_loss=0.014582, lap_loss=0.000941, lr=0.00353, time=13.9 ms, rem=1.79 m
# iter= 2270, img_loss=0.015223, lap_loss=0.000935, lr=0.00351, time=13.8 ms, rem=1.77 m
# iter= 2280, img_loss=0.014107, lap_loss=0.000948, lr=0.00350, time=13.9 ms, rem=1.79 m
# iter= 2290, img_loss=0.015476, lap_loss=0.000958, lr=0.00348, time=14.1 ms, rem=1.81 m
# iter= 2300, img_loss=0.016269, lap_loss=0.000943, lr=0.00347, time=13.7 ms, rem=1.75 m
# iter= 2310, img_loss=0.016580, lap_loss=0.000944, lr=0.00345, time=13.5 ms, rem=1.73 m
# iter= 2320, img_loss=0.014790, lap_loss=0.000962, lr=0.00343, time=13.9 ms, rem=1.78 m
# iter= 2330, img_loss=0.016792, lap_loss=0.000959, lr=0.00342, time=13.6 ms, rem=1.74 m
# iter= 2340, img_loss=0.014349, lap_loss=0.000970, lr=0.00340, time=13.6 ms, rem=1.74 m
# iter= 2350, img_loss=0.015203, lap_loss=0.000953, lr=0.00339, time=14.5 ms, rem=1.85 m
# iter= 2360, img_loss=0.015778, lap_loss=0.000975, lr=0.00337, time=13.7 ms, rem=1.74 m
# iter= 2370, img_loss=0.016497, lap_loss=0.001037, lr=0.00336, time=14.0 ms, rem=1.78 m
# iter= 2380, img_loss=0.014234, lap_loss=0.001040, lr=0.00334, time=13.5 ms, rem=1.71 m
# iter= 2390, img_loss=0.016636, lap_loss=0.001052, lr=0.00333, time=13.7 ms, rem=1.74 m
# iter= 2400, img_loss=0.015368, lap_loss=0.001024, lr=0.00331, time=14.1 ms, rem=1.79 m
# iter= 2410, img_loss=0.016472, lap_loss=0.001022, lr=0.00329, time=13.9 ms, rem=1.76 m
# iter= 2420, img_loss=0.015746, lap_loss=0.001039, lr=0.00328, time=13.9 ms, rem=1.75 m
# iter= 2430, img_loss=0.014642, lap_loss=0.001049, lr=0.00326, time=13.9 ms, rem=1.75 m
# iter= 2440, img_loss=0.016540, lap_loss=0.001025, lr=0.00325, time=13.5 ms, rem=1.70 m
# iter= 2450, img_loss=0.015560, lap_loss=0.000999, lr=0.00323, time=13.5 ms, rem=1.70 m
# iter= 2460, img_loss=0.012355, lap_loss=0.000973, lr=0.00322, time=15.0 ms, rem=1.88 m
# iter= 2470, img_loss=0.016409, lap_loss=0.000944, lr=0.00320, time=14.1 ms, rem=1.77 m
# iter= 2480, img_loss=0.014750, lap_loss=0.000959, lr=0.00319, time=14.0 ms, rem=1.76 m
# iter= 2490, img_loss=0.016868, lap_loss=0.000983, lr=0.00318, time=14.0 ms, rem=1.75 m
# iter= 2500, img_loss=0.014507, lap_loss=0.001016, lr=0.00316, time=13.5 ms, rem=1.69 m
# iter= 2510, img_loss=0.016931, lap_loss=0.000994, lr=0.00315, time=13.9 ms, rem=1.73 m
# iter= 2520, img_loss=0.014483, lap_loss=0.000989, lr=0.00313, time=13.9 ms, rem=1.73 m
# iter= 2530, img_loss=0.015897, lap_loss=0.001008, lr=0.00312, time=13.5 ms, rem=1.68 m
# iter= 2540, img_loss=0.017123, lap_loss=0.000999, lr=0.00310, time=13.7 ms, rem=1.70 m
# iter= 2550, img_loss=0.016665, lap_loss=0.001002, lr=0.00309, time=13.7 ms, rem=1.71 m
# iter= 2560, img_loss=0.014829, lap_loss=0.001017, lr=0.00307, time=14.3 ms, rem=1.77 m
# iter= 2570, img_loss=0.015092, lap_loss=0.001013, lr=0.00306, time=14.1 ms, rem=1.74 m
# iter= 2580, img_loss=0.015576, lap_loss=0.001009, lr=0.00305, time=14.0 ms, rem=1.73 m
# iter= 2590, img_loss=0.018070, lap_loss=0.001044, lr=0.00303, time=14.3 ms, rem=1.77 m
# iter= 2600, img_loss=0.015887, lap_loss=0.001053, lr=0.00302, time=14.0 ms, rem=1.72 m
# iter= 2610, img_loss=0.016496, lap_loss=0.001065, lr=0.00300, time=14.1 ms, rem=1.73 m
# iter= 2620, img_loss=0.014474, lap_loss=0.001050, lr=0.00299, time=13.8 ms, rem=1.69 m
# iter= 2630, img_loss=0.015838, lap_loss=0.001043, lr=0.00298, time=14.6 ms, rem=1.79 m
# iter= 2640, img_loss=0.014987, lap_loss=0.001060, lr=0.00296, time=13.2 ms, rem=1.62 m
# iter= 2650, img_loss=0.014449, lap_loss=0.001083, lr=0.00295, time=13.8 ms, rem=1.68 m
# iter= 2660, img_loss=0.015967, lap_loss=0.001094, lr=0.00294, time=14.2 ms, rem=1.73 m
# iter= 2670, img_loss=0.015052, lap_loss=0.001121, lr=0.00292, time=14.0 ms, rem=1.71 m
# iter= 2680, img_loss=0.015730, lap_loss=0.001084, lr=0.00291, time=13.7 ms, rem=1.67 m
# iter= 2690, img_loss=0.015347, lap_loss=0.001079, lr=0.00290, time=14.0 ms, rem=1.71 m
# iter= 2700, img_loss=0.015409, lap_loss=0.001085, lr=0.00288, time=15.2 ms, rem=1.85 m
# iter= 2710, img_loss=0.015540, lap_loss=0.001112, lr=0.00287, time=13.4 ms, rem=1.63 m
# iter= 2720, img_loss=0.015144, lap_loss=0.001111, lr=0.00286, time=13.7 ms, rem=1.66 m
# iter= 2730, img_loss=0.013103, lap_loss=0.001095, lr=0.00284, time=13.7 ms, rem=1.66 m
# iter= 2740, img_loss=0.015853, lap_loss=0.001106, lr=0.00283, time=13.8 ms, rem=1.67 m
# iter= 2750, img_loss=0.014072, lap_loss=0.001091, lr=0.00282, time=13.5 ms, rem=1.63 m
# iter= 2760, img_loss=0.013349, lap_loss=0.001079, lr=0.00280, time=14.0 ms, rem=1.69 m
# iter= 2770, img_loss=0.014217, lap_loss=0.001070, lr=0.00279, time=14.8 ms, rem=1.78 m
# iter= 2780, img_loss=0.015124, lap_loss=0.001057, lr=0.00278, time=13.9 ms, rem=1.67 m
# iter= 2790, img_loss=0.014370, lap_loss=0.001088, lr=0.00277, time=13.9 ms, rem=1.67 m
# iter= 2800, img_loss=0.013929, lap_loss=0.001110, lr=0.00275, time=14.4 ms, rem=1.73 m
# iter= 2810, img_loss=0.016177, lap_loss=0.001094, lr=0.00274, time=14.2 ms, rem=1.70 m
# iter= 2820, img_loss=0.014564, lap_loss=0.001086, lr=0.00273, time=14.8 ms, rem=1.77 m
# iter= 2830, img_loss=0.014191, lap_loss=0.001095, lr=0.00272, time=14.5 ms, rem=1.73 m
# iter= 2840, img_loss=0.015182, lap_loss=0.001080, lr=0.00270, time=14.0 ms, rem=1.67 m
# iter= 2850, img_loss=0.016196, lap_loss=0.001085, lr=0.00269, time=13.8 ms, rem=1.64 m
# iter= 2860, img_loss=0.016372, lap_loss=0.001084, lr=0.00268, time=13.6 ms, rem=1.62 m
# iter= 2870, img_loss=0.014582, lap_loss=0.001073, lr=0.00267, time=13.9 ms, rem=1.65 m
# iter= 2880, img_loss=0.016878, lap_loss=0.001078, lr=0.00265, time=13.5 ms, rem=1.60 m
# iter= 2890, img_loss=0.013764, lap_loss=0.001096, lr=0.00264, time=13.5 ms, rem=1.60 m
# iter= 2900, img_loss=0.014924, lap_loss=0.001096, lr=0.00263, time=13.9 ms, rem=1.65 m
# iter= 2910, img_loss=0.014567, lap_loss=0.001092, lr=0.00262, time=14.4 ms, rem=1.70 m
# iter= 2920, img_loss=0.015684, lap_loss=0.001103, lr=0.00260, time=14.0 ms, rem=1.65 m
# iter= 2930, img_loss=0.014883, lap_loss=0.001106, lr=0.00259, time=13.6 ms, rem=1.61 m
# iter= 2940, img_loss=0.013368, lap_loss=0.001081, lr=0.00258, time=13.7 ms, rem=1.61 m
# iter= 2950, img_loss=0.014123, lap_loss=0.001076, lr=0.00257, time=13.7 ms, rem=1.61 m
# iter= 2960, img_loss=0.016447, lap_loss=0.001074, lr=0.00256, time=14.0 ms, rem=1.64 m
# iter= 2970, img_loss=0.014285, lap_loss=0.001078, lr=0.00255, time=14.4 ms, rem=1.69 m
# iter= 2980, img_loss=0.012804, lap_loss=0.001077, lr=0.00253, time=14.2 ms, rem=1.66 m
# iter= 2990, img_loss=0.015611, lap_loss=0.001056, lr=0.00252, time=14.0 ms, rem=1.63 m
# iter= 3000, img_loss=0.016170, lap_loss=0.001060, lr=0.00251, time=13.5 ms, rem=1.57 m
# iter= 3010, img_loss=0.014005, lap_loss=0.001073, lr=0.00250, time=13.8 ms, rem=1.61 m
# iter= 3020, img_loss=0.014643, lap_loss=0.001082, lr=0.00249, time=13.5 ms, rem=1.57 m
# iter= 3030, img_loss=0.012498, lap_loss=0.001090, lr=0.00248, time=13.8 ms, rem=1.60 m
# iter= 3040, img_loss=0.013151, lap_loss=0.001084, lr=0.00246, time=14.3 ms, rem=1.66 m
# iter= 3050, img_loss=0.015285, lap_loss=0.001079, lr=0.00245, time=14.8 ms, rem=1.71 m
# iter= 3060, img_loss=0.014888, lap_loss=0.001099, lr=0.00244, time=15.4 ms, rem=1.78 m
# iter= 3070, img_loss=0.015883, lap_loss=0.001099, lr=0.00243, time=14.9 ms, rem=1.72 m
# iter= 3080, img_loss=0.014539, lap_loss=0.001105, lr=0.00242, time=13.8 ms, rem=1.59 m
# iter= 3090, img_loss=0.014283, lap_loss=0.001096, lr=0.00241, time=13.8 ms, rem=1.59 m
# iter= 3100, img_loss=0.014257, lap_loss=0.001075, lr=0.00240, time=13.9 ms, rem=1.60 m
# iter= 3110, img_loss=0.015153, lap_loss=0.001072, lr=0.00239, time=13.9 ms, rem=1.59 m
# iter= 3120, img_loss=0.013769, lap_loss=0.001083, lr=0.00238, time=13.9 ms, rem=1.59 m
# iter= 3130, img_loss=0.015003, lap_loss=0.001072, lr=0.00236, time=13.7 ms, rem=1.57 m
# iter= 3140, img_loss=0.014425, lap_loss=0.001062, lr=0.00235, time=13.9 ms, rem=1.59 m
# iter= 3150, img_loss=0.012775, lap_loss=0.001079, lr=0.00234, time=14.9 ms, rem=1.70 m
# iter= 3160, img_loss=0.013572, lap_loss=0.001075, lr=0.00233, time=14.2 ms, rem=1.62 m
# iter= 3170, img_loss=0.015155, lap_loss=0.001080, lr=0.00232, time=15.3 ms, rem=1.74 m
# iter= 3180, img_loss=0.016154, lap_loss=0.001116, lr=0.00231, time=14.5 ms, rem=1.64 m
# iter= 3190, img_loss=0.011842, lap_loss=0.001119, lr=0.00230, time=14.6 ms, rem=1.66 m
# iter= 3200, img_loss=0.015271, lap_loss=0.001112, lr=0.00229, time=14.6 ms, rem=1.65 m
# iter= 3210, img_loss=0.013985, lap_loss=0.001111, lr=0.00228, time=13.6 ms, rem=1.54 m
# iter= 3220, img_loss=0.014589, lap_loss=0.001102, lr=0.00227, time=13.8 ms, rem=1.56 m
# iter= 3230, img_loss=0.015029, lap_loss=0.001101, lr=0.00226, time=13.5 ms, rem=1.52 m
# iter= 3240, img_loss=0.016081, lap_loss=0.001116, lr=0.00225, time=14.2 ms, rem=1.60 m
# iter= 3250, img_loss=0.015434, lap_loss=0.001117, lr=0.00224, time=13.8 ms, rem=1.55 m
# iter= 3260, img_loss=0.014076, lap_loss=0.001118, lr=0.00223, time=13.9 ms, rem=1.56 m
# iter= 3270, img_loss=0.015437, lap_loss=0.001125, lr=0.00222, time=14.0 ms, rem=1.57 m
# iter= 3280, img_loss=0.014857, lap_loss=0.001115, lr=0.00221, time=16.5 ms, rem=1.85 m
# iter= 3290, img_loss=0.015764, lap_loss=0.001117, lr=0.00220, time=15.4 ms, rem=1.72 m
# iter= 3300, img_loss=0.013128, lap_loss=0.001111, lr=0.00219, time=15.7 ms, rem=1.75 m
# iter= 3310, img_loss=0.014827, lap_loss=0.001106, lr=0.00218, time=16.1 ms, rem=1.80 m
# iter= 3320, img_loss=0.014611, lap_loss=0.001097, lr=0.00217, time=16.4 ms, rem=1.83 m
# iter= 3330, img_loss=0.016487, lap_loss=0.001097, lr=0.00216, time=17.4 ms, rem=1.93 m
# iter= 3340, img_loss=0.014162, lap_loss=0.001102, lr=0.00215, time=20.3 ms, rem=2.25 m
# iter= 3350, img_loss=0.012902, lap_loss=0.001102, lr=0.00214, time=20.8 ms, rem=2.31 m
# iter= 3360, img_loss=0.013971, lap_loss=0.001093, lr=0.00213, time=18.4 ms, rem=2.04 m
# iter= 3370, img_loss=0.015792, lap_loss=0.001098, lr=0.00212, time=15.6 ms, rem=1.72 m
# iter= 3380, img_loss=0.013882, lap_loss=0.001106, lr=0.00211, time=16.3 ms, rem=1.80 m
# iter= 3390, img_loss=0.013156, lap_loss=0.001114, lr=0.00210, time=16.8 ms, rem=1.85 m
# iter= 3400, img_loss=0.015905, lap_loss=0.001121, lr=0.00209, time=15.4 ms, rem=1.69 m
# iter= 3410, img_loss=0.014202, lap_loss=0.001123, lr=0.00208, time=15.2 ms, rem=1.67 m
# iter= 3420, img_loss=0.014199, lap_loss=0.001109, lr=0.00207, time=15.2 ms, rem=1.67 m
# iter= 3430, img_loss=0.012909, lap_loss=0.001096, lr=0.00206, time=13.8 ms, rem=1.51 m
# iter= 3440, img_loss=0.013275, lap_loss=0.001086, lr=0.00205, time=13.8 ms, rem=1.51 m
# iter= 3450, img_loss=0.012479, lap_loss=0.001070, lr=0.00204, time=14.2 ms, rem=1.55 m
# iter= 3460, img_loss=0.014790, lap_loss=0.001085, lr=0.00203, time=15.7 ms, rem=1.72 m
# iter= 3470, img_loss=0.014238, lap_loss=0.001105, lr=0.00202, time=15.6 ms, rem=1.69 m
# iter= 3480, img_loss=0.013289, lap_loss=0.001109, lr=0.00201, time=13.6 ms, rem=1.48 m
# iter= 3490, img_loss=0.011957, lap_loss=0.001107, lr=0.00200, time=14.2 ms, rem=1.54 m
# iter= 3500, img_loss=0.013865, lap_loss=0.001107, lr=0.00199, time=13.8 ms, rem=1.50 m
# iter= 3510, img_loss=0.013680, lap_loss=0.001100, lr=0.00199, time=14.3 ms, rem=1.54 m
# iter= 3520, img_loss=0.013585, lap_loss=0.001105, lr=0.00198, time=14.1 ms, rem=1.52 m
# iter= 3530, img_loss=0.013270, lap_loss=0.001115, lr=0.00197, time=14.2 ms, rem=1.53 m
# iter= 3540, img_loss=0.013289, lap_loss=0.001122, lr=0.00196, time=14.5 ms, rem=1.56 m
# iter= 3550, img_loss=0.012945, lap_loss=0.001117, lr=0.00195, time=13.7 ms, rem=1.47 m
# iter= 3560, img_loss=0.011972, lap_loss=0.001127, lr=0.00194, time=15.5 ms, rem=1.66 m
# iter= 3570, img_loss=0.014374, lap_loss=0.001129, lr=0.00193, time=14.0 ms, rem=1.50 m
# iter= 3580, img_loss=0.014102, lap_loss=0.001133, lr=0.00192, time=13.6 ms, rem=1.46 m
# iter= 3590, img_loss=0.012926, lap_loss=0.001145, lr=0.00191, time=13.8 ms, rem=1.47 m
# iter= 3600, img_loss=0.012612, lap_loss=0.001127, lr=0.00190, time=14.8 ms, rem=1.58 m
# iter= 3610, img_loss=0.014725, lap_loss=0.001104, lr=0.00190, time=13.7 ms, rem=1.46 m
# iter= 3620, img_loss=0.014345, lap_loss=0.001099, lr=0.00189, time=13.7 ms, rem=1.46 m
# iter= 3630, img_loss=0.014930, lap_loss=0.001102, lr=0.00188, time=14.8 ms, rem=1.57 m
# iter= 3640, img_loss=0.013703, lap_loss=0.001118, lr=0.00187, time=14.6 ms, rem=1.55 m
# iter= 3650, img_loss=0.014559, lap_loss=0.001119, lr=0.00186, time=14.3 ms, rem=1.51 m
# iter= 3660, img_loss=0.014494, lap_loss=0.001105, lr=0.00185, time=13.8 ms, rem=1.46 m
# iter= 3670, img_loss=0.013450, lap_loss=0.001114, lr=0.00184, time=14.6 ms, rem=1.54 m
# iter= 3680, img_loss=0.013743, lap_loss=0.001115, lr=0.00184, time=13.9 ms, rem=1.46 m
# iter= 3690, img_loss=0.013747, lap_loss=0.001103, lr=0.00183, time=13.6 ms, rem=1.43 m
# iter= 3700, img_loss=0.014037, lap_loss=0.001105, lr=0.00182, time=14.0 ms, rem=1.47 m
# iter= 3710, img_loss=0.015541, lap_loss=0.001106, lr=0.00181, time=13.9 ms, rem=1.46 m
# iter= 3720, img_loss=0.014171, lap_loss=0.001094, lr=0.00180, time=14.0 ms, rem=1.47 m
# iter= 3730, img_loss=0.012733, lap_loss=0.001093, lr=0.00179, time=15.4 ms, rem=1.61 m
# iter= 3740, img_loss=0.011968, lap_loss=0.001089, lr=0.00179, time=14.6 ms, rem=1.52 m
# iter= 3750, img_loss=0.012152, lap_loss=0.001082, lr=0.00178, time=13.8 ms, rem=1.43 m
# iter= 3760, img_loss=0.015377, lap_loss=0.001081, lr=0.00177, time=15.1 ms, rem=1.57 m
# iter= 3770, img_loss=0.014917, lap_loss=0.001076, lr=0.00176, time=15.5 ms, rem=1.60 m
# iter= 3780, img_loss=0.013378, lap_loss=0.001088, lr=0.00175, time=15.1 ms, rem=1.57 m
# iter= 3790, img_loss=0.012226, lap_loss=0.001095, lr=0.00175, time=17.3 ms, rem=1.79 m
# iter= 3800, img_loss=0.013851, lap_loss=0.001090, lr=0.00174, time=15.4 ms, rem=1.59 m
# iter= 3810, img_loss=0.013428, lap_loss=0.001089, lr=0.00173, time=17.1 ms, rem=1.76 m
# iter= 3820, img_loss=0.012042, lap_loss=0.001087, lr=0.00172, time=17.6 ms, rem=1.81 m
# iter= 3830, img_loss=0.012351, lap_loss=0.001085, lr=0.00171, time=18.0 ms, rem=1.85 m
# iter= 3840, img_loss=0.013590, lap_loss=0.001083, lr=0.00171, time=16.9 ms, rem=1.74 m
# iter= 3850, img_loss=0.013634, lap_loss=0.001091, lr=0.00170, time=16.9 ms, rem=1.73 m
# iter= 3860, img_loss=0.012880, lap_loss=0.001089, lr=0.00169, time=17.3 ms, rem=1.77 m
# iter= 3870, img_loss=0.011977, lap_loss=0.001100, lr=0.00168, time=19.0 ms, rem=1.94 m
# iter= 3880, img_loss=0.014769, lap_loss=0.001096, lr=0.00167, time=17.3 ms, rem=1.76 m
# iter= 3890, img_loss=0.012339, lap_loss=0.001086, lr=0.00167, time=15.3 ms, rem=1.56 m
# iter= 3900, img_loss=0.014268, lap_loss=0.001085, lr=0.00166, time=15.1 ms, rem=1.53 m
# iter= 3910, img_loss=0.013456, lap_loss=0.001086, lr=0.00165, time=16.5 ms, rem=1.67 m
# iter= 3920, img_loss=0.013541, lap_loss=0.001098, lr=0.00164, time=18.1 ms, rem=1.83 m
# iter= 3930, img_loss=0.014776, lap_loss=0.001120, lr=0.00164, time=16.6 ms, rem=1.68 m
# iter= 3940, img_loss=0.010447, lap_loss=0.001130, lr=0.00163, time=16.2 ms, rem=1.64 m
# iter= 3950, img_loss=0.013337, lap_loss=0.001129, lr=0.00162, time=14.4 ms, rem=1.45 m
# iter= 3960, img_loss=0.016369, lap_loss=0.001133, lr=0.00161, time=16.4 ms, rem=1.65 m
# iter= 3970, img_loss=0.012434, lap_loss=0.001129, lr=0.00161, time=15.0 ms, rem=1.51 m
# iter= 3980, img_loss=0.012632, lap_loss=0.001122, lr=0.00160, time=13.5 ms, rem=1.35 m
# iter= 3990, img_loss=0.014808, lap_loss=0.001116, lr=0.00159, time=13.6 ms, rem=1.36 m
# iter= 4000, img_loss=0.013489, lap_loss=0.001115, lr=0.00158, time=14.3 ms, rem=1.43 m
# iter= 4010, img_loss=0.012585, lap_loss=0.001119, lr=0.00158, time=14.2 ms, rem=1.42 m
# iter= 4020, img_loss=0.013777, lap_loss=0.001119, lr=0.00157, time=13.8 ms, rem=1.38 m
# iter= 4030, img_loss=0.015500, lap_loss=0.001120, lr=0.00156, time=13.4 ms, rem=1.33 m
# iter= 4040, img_loss=0.013703, lap_loss=0.001120, lr=0.00156, time=14.2 ms, rem=1.41 m
# iter= 4050, img_loss=0.012606, lap_loss=0.001120, lr=0.00155, time=16.4 ms, rem=1.63 m
# iter= 4060, img_loss=0.011870, lap_loss=0.001119, lr=0.00154, time=14.8 ms, rem=1.46 m
# iter= 4070, img_loss=0.014828, lap_loss=0.001113, lr=0.00153, time=15.4 ms, rem=1.52 m
# iter= 4080, img_loss=0.014605, lap_loss=0.001114, lr=0.00153, time=17.7 ms, rem=1.75 m
# iter= 4090, img_loss=0.013591, lap_loss=0.001110, lr=0.00152, time=16.8 ms, rem=1.65 m
# iter= 4100, img_loss=0.013708, lap_loss=0.001106, lr=0.00151, time=17.2 ms, rem=1.69 m
# iter= 4110, img_loss=0.013929, lap_loss=0.001111, lr=0.00151, time=15.5 ms, rem=1.53 m
# iter= 4120, img_loss=0.011779, lap_loss=0.001113, lr=0.00150, time=16.3 ms, rem=1.60 m
# iter= 4130, img_loss=0.013361, lap_loss=0.001115, lr=0.00149, time=17.8 ms, rem=1.74 m
# iter= 4140, img_loss=0.013304, lap_loss=0.001115, lr=0.00149, time=20.0 ms, rem=1.96 m
# iter= 4150, img_loss=0.012891, lap_loss=0.001114, lr=0.00148, time=20.2 ms, rem=1.97 m
# iter= 4160, img_loss=0.014217, lap_loss=0.001124, lr=0.00147, time=19.4 ms, rem=1.89 m
# iter= 4170, img_loss=0.013822, lap_loss=0.001136, lr=0.00146, time=18.7 ms, rem=1.81 m
# iter= 4180, img_loss=0.012704, lap_loss=0.001135, lr=0.00146, time=14.5 ms, rem=1.41 m
# iter= 4190, img_loss=0.012861, lap_loss=0.001126, lr=0.00145, time=16.3 ms, rem=1.58 m
# iter= 4200, img_loss=0.014890, lap_loss=0.001119, lr=0.00144, time=14.4 ms, rem=1.39 m
# iter= 4210, img_loss=0.014099, lap_loss=0.001127, lr=0.00144, time=13.7 ms, rem=1.32 m
# iter= 4220, img_loss=0.014975, lap_loss=0.001135, lr=0.00143, time=14.2 ms, rem=1.37 m
# iter= 4230, img_loss=0.013120, lap_loss=0.001136, lr=0.00142, time=13.6 ms, rem=1.30 m
# iter= 4240, img_loss=0.013650, lap_loss=0.001136, lr=0.00142, time=16.5 ms, rem=1.58 m
# iter= 4250, img_loss=0.013777, lap_loss=0.001146, lr=0.00141, time=15.6 ms, rem=1.49 m
# iter= 4260, img_loss=0.012930, lap_loss=0.001146, lr=0.00141, time=14.2 ms, rem=1.36 m
# iter= 4270, img_loss=0.011643, lap_loss=0.001133, lr=0.00140, time=14.0 ms, rem=1.34 m
# iter= 4280, img_loss=0.013014, lap_loss=0.001133, lr=0.00139, time=14.0 ms, rem=1.33 m
# iter= 4290, img_loss=0.012320, lap_loss=0.001135, lr=0.00139, time=13.7 ms, rem=1.30 m
# iter= 4300, img_loss=0.014218, lap_loss=0.001136, lr=0.00138, time=15.0 ms, rem=1.42 m
# iter= 4310, img_loss=0.013201, lap_loss=0.001134, lr=0.00137, time=14.0 ms, rem=1.33 m
# iter= 4320, img_loss=0.012234, lap_loss=0.001129, lr=0.00137, time=14.1 ms, rem=1.33 m
# iter= 4330, img_loss=0.014243, lap_loss=0.001133, lr=0.00136, time=13.9 ms, rem=1.32 m
# iter= 4340, img_loss=0.013339, lap_loss=0.001144, lr=0.00135, time=14.1 ms, rem=1.33 m
# iter= 4350, img_loss=0.013888, lap_loss=0.001146, lr=0.00135, time=13.9 ms, rem=1.31 m
# iter= 4360, img_loss=0.013545, lap_loss=0.001144, lr=0.00134, time=13.5 ms, rem=1.27 m
# iter= 4370, img_loss=0.012632, lap_loss=0.001140, lr=0.00134, time=13.6 ms, rem=1.27 m
# iter= 4380, img_loss=0.010816, lap_loss=0.001136, lr=0.00133, time=13.6 ms, rem=1.27 m
# iter= 4390, img_loss=0.012752, lap_loss=0.001133, lr=0.00132, time=14.1 ms, rem=1.32 m
# iter= 4400, img_loss=0.013159, lap_loss=0.001135, lr=0.00132, time=13.3 ms, rem=1.24 m
# iter= 4410, img_loss=0.013910, lap_loss=0.001132, lr=0.00131, time=14.1 ms, rem=1.31 m
# iter= 4420, img_loss=0.013513, lap_loss=0.001131, lr=0.00131, time=13.8 ms, rem=1.28 m
# iter= 4430, img_loss=0.013688, lap_loss=0.001129, lr=0.00130, time=14.4 ms, rem=1.33 m
# iter= 4440, img_loss=0.012129, lap_loss=0.001135, lr=0.00129, time=13.5 ms, rem=1.25 m
# iter= 4450, img_loss=0.013719, lap_loss=0.001135, lr=0.00129, time=14.1 ms, rem=1.30 m
# iter= 4460, img_loss=0.010890, lap_loss=0.001128, lr=0.00128, time=14.1 ms, rem=1.30 m
# iter= 4470, img_loss=0.013403, lap_loss=0.001119, lr=0.00128, time=14.7 ms, rem=1.36 m
# iter= 4480, img_loss=0.012016, lap_loss=0.001113, lr=0.00127, time=15.6 ms, rem=1.43 m
# iter= 4490, img_loss=0.012223, lap_loss=0.001108, lr=0.00126, time=14.7 ms, rem=1.35 m
# iter= 4500, img_loss=0.012165, lap_loss=0.001113, lr=0.00126, time=14.7 ms, rem=1.35 m
# iter= 4510, img_loss=0.014439, lap_loss=0.001124, lr=0.00125, time=13.5 ms, rem=1.24 m
# iter= 4520, img_loss=0.013356, lap_loss=0.001135, lr=0.00125, time=13.7 ms, rem=1.25 m
# iter= 4530, img_loss=0.013126, lap_loss=0.001138, lr=0.00124, time=14.6 ms, rem=1.33 m
# iter= 4540, img_loss=0.015081, lap_loss=0.001134, lr=0.00124, time=15.0 ms, rem=1.36 m
# iter= 4550, img_loss=0.014861, lap_loss=0.001130, lr=0.00123, time=15.8 ms, rem=1.44 m
# iter= 4560, img_loss=0.013635, lap_loss=0.001131, lr=0.00122, time=16.3 ms, rem=1.48 m
# iter= 4570, img_loss=0.012182, lap_loss=0.001136, lr=0.00122, time=15.0 ms, rem=1.36 m
# iter= 4580, img_loss=0.013100, lap_loss=0.001138, lr=0.00121, time=14.5 ms, rem=1.31 m
# iter= 4590, img_loss=0.014247, lap_loss=0.001137, lr=0.00121, time=14.8 ms, rem=1.33 m
# iter= 4600, img_loss=0.013071, lap_loss=0.001128, lr=0.00120, time=13.8 ms, rem=1.24 m
# iter= 4610, img_loss=0.013840, lap_loss=0.001123, lr=0.00120, time=13.5 ms, rem=1.21 m
# iter= 4620, img_loss=0.014131, lap_loss=0.001123, lr=0.00119, time=13.7 ms, rem=1.23 m
# iter= 4630, img_loss=0.014021, lap_loss=0.001125, lr=0.00119, time=14.5 ms, rem=1.30 m
# iter= 4640, img_loss=0.013440, lap_loss=0.001124, lr=0.00118, time=14.9 ms, rem=1.33 m
# iter= 4650, img_loss=0.012413, lap_loss=0.001122, lr=0.00117, time=14.7 ms, rem=1.31 m
# iter= 4660, img_loss=0.011179, lap_loss=0.001114, lr=0.00117, time=15.2 ms, rem=1.35 m
# iter= 4670, img_loss=0.013015, lap_loss=0.001107, lr=0.00116, time=16.7 ms, rem=1.48 m
# iter= 4680, img_loss=0.011467, lap_loss=0.001118, lr=0.00116, time=15.1 ms, rem=1.34 m
# iter= 4690, img_loss=0.012487, lap_loss=0.001122, lr=0.00115, time=16.1 ms, rem=1.43 m
# iter= 4700, img_loss=0.009527, lap_loss=0.001116, lr=0.00115, time=15.1 ms, rem=1.33 m
# iter= 4710, img_loss=0.014376, lap_loss=0.001111, lr=0.00114, time=15.6 ms, rem=1.38 m
# iter= 4720, img_loss=0.013389, lap_loss=0.001111, lr=0.00114, time=15.5 ms, rem=1.36 m
# iter= 4730, img_loss=0.013719, lap_loss=0.001111, lr=0.00113, time=15.6 ms, rem=1.37 m
# iter= 4740, img_loss=0.010727, lap_loss=0.001116, lr=0.00113, time=14.9 ms, rem=1.31 m
# iter= 4750, img_loss=0.015232, lap_loss=0.001119, lr=0.00112, time=16.3 ms, rem=1.42 m
# iter= 4760, img_loss=0.012729, lap_loss=0.001116, lr=0.00112, time=15.3 ms, rem=1.34 m
# iter= 4770, img_loss=0.014273, lap_loss=0.001112, lr=0.00111, time=15.2 ms, rem=1.32 m
# iter= 4780, img_loss=0.011467, lap_loss=0.001113, lr=0.00111, time=15.8 ms, rem=1.38 m
# iter= 4790, img_loss=0.012485, lap_loss=0.001107, lr=0.00110, time=15.9 ms, rem=1.38 m
# iter= 4800, img_loss=0.012150, lap_loss=0.001101, lr=0.00110, time=14.8 ms, rem=1.28 m
# iter= 4810, img_loss=0.011491, lap_loss=0.001100, lr=0.00109, time=15.0 ms, rem=1.30 m
# iter= 4820, img_loss=0.013490, lap_loss=0.001098, lr=0.00109, time=14.7 ms, rem=1.27 m
# iter= 4830, img_loss=0.011193, lap_loss=0.001102, lr=0.00108, time=14.2 ms, rem=1.22 m
# iter= 4840, img_loss=0.013342, lap_loss=0.001108, lr=0.00108, time=14.1 ms, rem=1.21 m
# iter= 4850, img_loss=0.011999, lap_loss=0.001111, lr=0.00107, time=14.3 ms, rem=1.23 m
# iter= 4860, img_loss=0.011450, lap_loss=0.001110, lr=0.00107, time=14.7 ms, rem=1.26 m
# iter= 4870, img_loss=0.011666, lap_loss=0.001109, lr=0.00106, time=14.5 ms, rem=1.24 m
# iter= 4880, img_loss=0.014097, lap_loss=0.001106, lr=0.00106, time=13.8 ms, rem=1.18 m
# iter= 4890, img_loss=0.012929, lap_loss=0.001106, lr=0.00105, time=13.5 ms, rem=1.15 m
# iter= 4900, img_loss=0.011288, lap_loss=0.001107, lr=0.00105, time=14.1 ms, rem=1.20 m
# iter= 4910, img_loss=0.012714, lap_loss=0.001104, lr=0.00104, time=14.1 ms, rem=1.20 m
# iter= 4920, img_loss=0.014371, lap_loss=0.001096, lr=0.00104, time=13.5 ms, rem=1.15 m
# iter= 4930, img_loss=0.013565, lap_loss=0.001096, lr=0.00103, time=15.2 ms, rem=1.28 m
# iter= 4940, img_loss=0.014297, lap_loss=0.001098, lr=0.00103, time=14.3 ms, rem=1.21 m
# iter= 4950, img_loss=0.011889, lap_loss=0.001102, lr=0.00102, time=15.2 ms, rem=1.28 m
# iter= 4960, img_loss=0.011915, lap_loss=0.001105, lr=0.00102, time=14.3 ms, rem=1.20 m
# iter= 4970, img_loss=0.009875, lap_loss=0.001103, lr=0.00101, time=14.7 ms, rem=1.23 m
# iter= 4980, img_loss=0.012156, lap_loss=0.001100, lr=0.00101, time=14.1 ms, rem=1.18 m
# iter= 4990, img_loss=0.011986, lap_loss=0.001101, lr=0.00100, time=13.7 ms, rem=1.14 m
# iter= 5000, img_loss=0.011079, lap_loss=0.001097, lr=0.00100, time=13.6 ms, rem=1.13 m
# iter= 5010, img_loss=0.012375, lap_loss=0.001096, lr=0.00099, time=13.6 ms, rem=1.13 m
# iter= 5020, img_loss=0.014390, lap_loss=0.001096, lr=0.00099, time=13.5 ms, rem=1.12 m
# iter= 5030, img_loss=0.013411, lap_loss=0.001102, lr=0.00099, time=13.8 ms, rem=1.14 m
# iter= 5040, img_loss=0.011117, lap_loss=0.001101, lr=0.00098, time=13.9 ms, rem=1.15 m
# iter= 5050, img_loss=0.013024, lap_loss=0.001092, lr=0.00098, time=14.2 ms, rem=1.17 m
# iter= 5060, img_loss=0.012675, lap_loss=0.001090, lr=0.00097, time=13.5 ms, rem=1.11 m
# iter= 5070, img_loss=0.013853, lap_loss=0.001106, lr=0.00097, time=14.3 ms, rem=1.17 m
# iter= 5080, img_loss=0.012989, lap_loss=0.001115, lr=0.00096, time=13.7 ms, rem=1.12 m
# iter= 5090, img_loss=0.014670, lap_loss=0.001116, lr=0.00096, time=13.6 ms, rem=1.11 m
# iter= 5100, img_loss=0.012155, lap_loss=0.001118, lr=0.00095, time=14.0 ms, rem=1.14 m
# iter= 5110, img_loss=0.013000, lap_loss=0.001113, lr=0.00095, time=14.2 ms, rem=1.16 m
# iter= 5120, img_loss=0.011208, lap_loss=0.001105, lr=0.00095, time=14.2 ms, rem=1.15 m
# iter= 5130, img_loss=0.012037, lap_loss=0.001096, lr=0.00094, time=14.0 ms, rem=1.14 m
# iter= 5140, img_loss=0.012547, lap_loss=0.001097, lr=0.00094, time=13.7 ms, rem=1.11 m
# iter= 5150, img_loss=0.012132, lap_loss=0.001097, lr=0.00093, time=13.9 ms, rem=1.12 m
# iter= 5160, img_loss=0.012815, lap_loss=0.001100, lr=0.00093, time=14.1 ms, rem=1.14 m
# iter= 5170, img_loss=0.013058, lap_loss=0.001103, lr=0.00092, time=14.7 ms, rem=1.18 m
# iter= 5180, img_loss=0.012537, lap_loss=0.001103, lr=0.00092, time=14.3 ms, rem=1.15 m
# iter= 5190, img_loss=0.013156, lap_loss=0.001103, lr=0.00092, time=15.6 ms, rem=1.25 m
# iter= 5200, img_loss=0.010991, lap_loss=0.001104, lr=0.00091, time=13.8 ms, rem=1.10 m
# iter= 5210, img_loss=0.012168, lap_loss=0.001099, lr=0.00091, time=14.0 ms, rem=1.12 m
# iter= 5220, img_loss=0.012101, lap_loss=0.001097, lr=0.00090, time=14.1 ms, rem=1.12 m
# iter= 5230, img_loss=0.012137, lap_loss=0.001097, lr=0.00090, time=14.0 ms, rem=1.11 m
# iter= 5240, img_loss=0.013705, lap_loss=0.001091, lr=0.00089, time=13.6 ms, rem=1.08 m
# iter= 5250, img_loss=0.013731, lap_loss=0.001093, lr=0.00089, time=13.6 ms, rem=1.07 m
# iter= 5260, img_loss=0.012387, lap_loss=0.001091, lr=0.00089, time=13.7 ms, rem=1.08 m
# iter= 5270, img_loss=0.013611, lap_loss=0.001088, lr=0.00088, time=14.0 ms, rem=1.10 m
# iter= 5280, img_loss=0.012983, lap_loss=0.001084, lr=0.00088, time=13.7 ms, rem=1.08 m
# iter= 5290, img_loss=0.011498, lap_loss=0.001083, lr=0.00087, time=13.7 ms, rem=1.08 m
# iter= 5300, img_loss=0.012025, lap_loss=0.001083, lr=0.00087, time=13.5 ms, rem=1.06 m
# iter= 5310, img_loss=0.012739, lap_loss=0.001084, lr=0.00087, time=13.5 ms, rem=1.05 m
# iter= 5320, img_loss=0.012263, lap_loss=0.001086, lr=0.00086, time=13.6 ms, rem=1.06 m
# iter= 5330, img_loss=0.012195, lap_loss=0.001084, lr=0.00086, time=14.0 ms, rem=1.09 m
# iter= 5340, img_loss=0.012376, lap_loss=0.001081, lr=0.00085, time=13.7 ms, rem=1.06 m
# iter= 5350, img_loss=0.012664, lap_loss=0.001082, lr=0.00085, time=13.8 ms, rem=1.07 m
# iter= 5360, img_loss=0.012257, lap_loss=0.001085, lr=0.00085, time=13.6 ms, rem=1.05 m
# iter= 5370, img_loss=0.014206, lap_loss=0.001093, lr=0.00084, time=13.8 ms, rem=1.07 m
# iter= 5380, img_loss=0.012463, lap_loss=0.001092, lr=0.00084, time=13.6 ms, rem=1.05 m
# iter= 5390, img_loss=0.012176, lap_loss=0.001092, lr=0.00084, time=13.9 ms, rem=1.06 m
# iter= 5400, img_loss=0.012338, lap_loss=0.001089, lr=0.00083, time=14.0 ms, rem=1.07 m
# iter= 5410, img_loss=0.013381, lap_loss=0.001090, lr=0.00083, time=14.3 ms, rem=1.10 m
# iter= 5420, img_loss=0.010442, lap_loss=0.001093, lr=0.00082, time=13.7 ms, rem=1.04 m
# iter= 5430, img_loss=0.013603, lap_loss=0.001088, lr=0.00082, time=14.0 ms, rem=1.07 m
# iter= 5440, img_loss=0.011785, lap_loss=0.001093, lr=0.00082, time=13.7 ms, rem=1.04 m
# iter= 5450, img_loss=0.013346, lap_loss=0.001097, lr=0.00081, time=13.8 ms, rem=1.05 m
# iter= 5460, img_loss=0.011552, lap_loss=0.001093, lr=0.00081, time=14.0 ms, rem=1.06 m
# iter= 5470, img_loss=0.011874, lap_loss=0.001091, lr=0.00081, time=13.6 ms, rem=1.03 m
# iter= 5480, img_loss=0.012834, lap_loss=0.001094, lr=0.00080, time=14.2 ms, rem=1.07 m
# iter= 5490, img_loss=0.013248, lap_loss=0.001095, lr=0.00080, time=14.1 ms, rem=1.06 m
# iter= 5500, img_loss=0.013844, lap_loss=0.001094, lr=0.00079, time=13.6 ms, rem=1.02 m
# ...
# iter= 8220, img_loss=0.011440, lap_loss=0.001110, lr=0.00023, time=15.7 ms, rem=28.01 s
# iter= 8230, img_loss=0.011424, lap_loss=0.001109, lr=0.00023, time=14.3 ms, rem=25.36 s
# iter= 8240, img_loss=0.013200, lap_loss=0.001110, lr=0.00022, time=14.7 ms, rem=25.93 s
# iter= 8250, img_loss=0.010889, lap_loss=0.001110, lr=0.00022, time=19.8 ms, rem=34.59 s
# iter= 8260, img_loss=0.011109, lap_loss=0.001108, lr=0.00022, time=15.6 ms, rem=27.12 s
# iter= 8270, img_loss=0.013133, lap_loss=0.001108, lr=0.00022, time=14.2 ms, rem=24.49 s
# iter= 8280, img_loss=0.011078, lap_loss=0.001109, lr=0.00022, time=14.2 ms, rem=24.38 s
# iter= 8290, img_loss=0.012469, lap_loss=0.001109, lr=0.00022, time=15.1 ms, rem=25.77 s
# iter= 8300, img_loss=0.010589, lap_loss=0.001110, lr=0.00022, time=14.7 ms, rem=24.99 s
# iter= 8310, img_loss=0.012335, lap_loss=0.001110, lr=0.00022, time=15.6 ms, rem=26.40 s
# iter= 8320, img_loss=0.011101, lap_loss=0.001111, lr=0.00022, time=17.8 ms, rem=29.83 s
# iter= 8330, img_loss=0.010548, lap_loss=0.001111, lr=0.00022, time=14.4 ms, rem=24.05 s
# iter= 8340, img_loss=0.011587, lap_loss=0.001110, lr=0.00021, time=14.2 ms, rem=23.52 s
# iter= 8350, img_loss=0.012036, lap_loss=0.001111, lr=0.00021, time=14.5 ms, rem=23.85 s
# iter= 8360, img_loss=0.010841, lap_loss=0.001112, lr=0.00021, time=13.9 ms, rem=22.80 s
# iter= 8370, img_loss=0.012638, lap_loss=0.001113, lr=0.00021, time=13.7 ms, rem=22.29 s
# iter= 8380, img_loss=0.010520, lap_loss=0.001112, lr=0.00021, time=14.1 ms, rem=22.84 s
# iter= 8390, img_loss=0.011146, lap_loss=0.001112, lr=0.00021, time=13.8 ms, rem=22.20 s
# iter= 8400, img_loss=0.009915, lap_loss=0.001111, lr=0.00021, time=13.6 ms, rem=21.78 s
# iter= 8410, img_loss=0.012636, lap_loss=0.001110, lr=0.00021, time=13.8 ms, rem=21.94 s
# iter= 8420, img_loss=0.010778, lap_loss=0.001110, lr=0.00021, time=15.0 ms, rem=23.71 s
# iter= 8430, img_loss=0.010382, lap_loss=0.001110, lr=0.00021, time=15.2 ms, rem=23.86 s
# iter= 8440, img_loss=0.011292, lap_loss=0.001109, lr=0.00021, time=14.7 ms, rem=22.93 s
# iter= 8450, img_loss=0.012036, lap_loss=0.001110, lr=0.00020, time=14.3 ms, rem=22.17 s
# iter= 8460, img_loss=0.011752, lap_loss=0.001110, lr=0.00020, time=14.3 ms, rem=21.95 s
# iter= 8470, img_loss=0.011526, lap_loss=0.001111, lr=0.00020, time=15.3 ms, rem=23.35 s
# iter= 8480, img_loss=0.011163, lap_loss=0.001111, lr=0.00020, time=16.1 ms, rem=24.48 s
# iter= 8490, img_loss=0.014465, lap_loss=0.001111, lr=0.00020, time=16.2 ms, rem=24.47 s
# iter= 8500, img_loss=0.012298, lap_loss=0.001111, lr=0.00020, time=17.5 ms, rem=26.22 s
# iter= 8510, img_loss=0.011428, lap_loss=0.001112, lr=0.00020, time=15.3 ms, rem=22.80 s
# iter= 8520, img_loss=0.010846, lap_loss=0.001113, lr=0.00020, time=15.7 ms, rem=23.21 s
# iter= 8530, img_loss=0.010815, lap_loss=0.001113, lr=0.00020, time=14.2 ms, rem=20.87 s
# iter= 8540, img_loss=0.010358, lap_loss=0.001113, lr=0.00020, time=14.4 ms, rem=21.10 s
# iter= 8550, img_loss=0.010537, lap_loss=0.001112, lr=0.00019, time=15.5 ms, rem=22.47 s
# iter= 8560, img_loss=0.011953, lap_loss=0.001112, lr=0.00019, time=14.7 ms, rem=21.17 s
# iter= 8570, img_loss=0.012587, lap_loss=0.001112, lr=0.00019, time=14.3 ms, rem=20.49 s
# iter= 8580, img_loss=0.010965, lap_loss=0.001112, lr=0.00019, time=14.4 ms, rem=20.49 s
# iter= 8590, img_loss=0.010637, lap_loss=0.001112, lr=0.00019, time=13.5 ms, rem=19.10 s
# iter= 8600, img_loss=0.011570, lap_loss=0.001111, lr=0.00019, time=14.3 ms, rem=20.00 s
# iter= 8610, img_loss=0.011747, lap_loss=0.001110, lr=0.00019, time=13.8 ms, rem=19.20 s
# iter= 8620, img_loss=0.010946, lap_loss=0.001110, lr=0.00019, time=13.7 ms, rem=18.89 s
# iter= 8630, img_loss=0.012563, lap_loss=0.001110, lr=0.00019, time=13.9 ms, rem=19.09 s
# iter= 8640, img_loss=0.010363, lap_loss=0.001111, lr=0.00019, time=13.9 ms, rem=18.95 s
# iter= 8650, img_loss=0.011953, lap_loss=0.001114, lr=0.00019, time=13.9 ms, rem=18.82 s
# iter= 8660, img_loss=0.012666, lap_loss=0.001115, lr=0.00019, time=14.0 ms, rem=18.76 s
# iter= 8670, img_loss=0.012207, lap_loss=0.001117, lr=0.00018, time=13.9 ms, rem=18.49 s
# iter= 8680, img_loss=0.011106, lap_loss=0.001117, lr=0.00018, time=14.6 ms, rem=19.28 s
# iter= 8690, img_loss=0.011482, lap_loss=0.001117, lr=0.00018, time=13.9 ms, rem=18.20 s
# iter= 8700, img_loss=0.011093, lap_loss=0.001115, lr=0.00018, time=14.8 ms, rem=19.25 s
# iter= 8710, img_loss=0.011977, lap_loss=0.001114, lr=0.00018, time=14.9 ms, rem=19.23 s
# iter= 8720, img_loss=0.009751, lap_loss=0.001114, lr=0.00018, time=14.2 ms, rem=18.13 s
# iter= 8730, img_loss=0.010848, lap_loss=0.001113, lr=0.00018, time=15.5 ms, rem=19.63 s
# iter= 8740, img_loss=0.012627, lap_loss=0.001113, lr=0.00018, time=13.5 ms, rem=16.96 s
# iter= 8750, img_loss=0.014769, lap_loss=0.001113, lr=0.00018, time=13.2 ms, rem=16.47 s
# iter= 8760, img_loss=0.011317, lap_loss=0.001115, lr=0.00018, time=13.5 ms, rem=16.71 s
# iter= 8770, img_loss=0.012464, lap_loss=0.001116, lr=0.00018, time=14.3 ms, rem=17.54 s
# iter= 8780, img_loss=0.009397, lap_loss=0.001116, lr=0.00018, time=15.8 ms, rem=19.24 s
# iter= 8790, img_loss=0.011196, lap_loss=0.001115, lr=0.00017, time=15.8 ms, rem=19.12 s
# iter= 8800, img_loss=0.012705, lap_loss=0.001115, lr=0.00017, time=16.6 ms, rem=19.92 s
# iter= 8810, img_loss=0.013778, lap_loss=0.001115, lr=0.00017, time=14.5 ms, rem=17.23 s
# iter= 8820, img_loss=0.012746, lap_loss=0.001116, lr=0.00017, time=14.0 ms, rem=16.53 s
# iter= 8830, img_loss=0.009995, lap_loss=0.001117, lr=0.00017, time=14.2 ms, rem=16.61 s
# iter= 8840, img_loss=0.009271, lap_loss=0.001117, lr=0.00017, time=14.0 ms, rem=16.19 s
# iter= 8850, img_loss=0.011086, lap_loss=0.001117, lr=0.00017, time=14.0 ms, rem=16.11 s
# iter= 8860, img_loss=0.010784, lap_loss=0.001116, lr=0.00017, time=14.3 ms, rem=16.28 s
# iter= 8870, img_loss=0.011194, lap_loss=0.001115, lr=0.00017, time=13.7 ms, rem=15.47 s
# iter= 8880, img_loss=0.011454, lap_loss=0.001114, lr=0.00017, time=14.1 ms, rem=15.76 s
# iter= 8890, img_loss=0.011865, lap_loss=0.001114, lr=0.00017, time=14.0 ms, rem=15.54 s
# iter= 8900, img_loss=0.012397, lap_loss=0.001114, lr=0.00017, time=13.8 ms, rem=15.18 s
# iter= 8910, img_loss=0.011443, lap_loss=0.001115, lr=0.00017, time=13.9 ms, rem=15.15 s
# iter= 8920, img_loss=0.010290, lap_loss=0.001115, lr=0.00016, time=14.2 ms, rem=15.34 s
# iter= 8930, img_loss=0.012201, lap_loss=0.001115, lr=0.00016, time=14.0 ms, rem=14.95 s
# iter= 8940, img_loss=0.011670, lap_loss=0.001114, lr=0.00016, time=14.1 ms, rem=14.93 s
# iter= 8950, img_loss=0.012474, lap_loss=0.001114, lr=0.00016, time=14.2 ms, rem=14.91 s
# iter= 8960, img_loss=0.011323, lap_loss=0.001114, lr=0.00016, time=13.7 ms, rem=14.20 s
# iter= 8970, img_loss=0.012239, lap_loss=0.001114, lr=0.00016, time=13.7 ms, rem=14.11 s
# iter= 8980, img_loss=0.010168, lap_loss=0.001115, lr=0.00016, time=14.0 ms, rem=14.28 s
# iter= 8990, img_loss=0.011846, lap_loss=0.001114, lr=0.00016, time=13.4 ms, rem=13.52 s
# iter= 9000, img_loss=0.012117, lap_loss=0.001114, lr=0.00016, time=13.5 ms, rem=13.50 s
# iter= 9010, img_loss=0.010952, lap_loss=0.001114, lr=0.00016, time=13.6 ms, rem=13.45 s
# iter= 9020, img_loss=0.011997, lap_loss=0.001113, lr=0.00016, time=15.5 ms, rem=15.17 s
# iter= 9030, img_loss=0.010770, lap_loss=0.001113, lr=0.00016, time=17.3 ms, rem=16.78 s
# iter= 9040, img_loss=0.011748, lap_loss=0.001113, lr=0.00016, time=15.2 ms, rem=14.62 s
# iter= 9050, img_loss=0.010137, lap_loss=0.001113, lr=0.00015, time=16.9 ms, rem=16.04 s
# iter= 9060, img_loss=0.011926, lap_loss=0.001114, lr=0.00015, time=16.0 ms, rem=15.03 s
# iter= 9070, img_loss=0.013967, lap_loss=0.001114, lr=0.00015, time=14.7 ms, rem=13.65 s
# iter= 9080, img_loss=0.011522, lap_loss=0.001115, lr=0.00015, time=14.6 ms, rem=13.41 s
# iter= 9090, img_loss=0.011435, lap_loss=0.001116, lr=0.00015, time=15.2 ms, rem=13.79 s
# iter= 9100, img_loss=0.011274, lap_loss=0.001116, lr=0.00015, time=14.5 ms, rem=13.03 s
# iter= 9110, img_loss=0.011432, lap_loss=0.001115, lr=0.00015, time=14.5 ms, rem=12.91 s
# iter= 9120, img_loss=0.012853, lap_loss=0.001115, lr=0.00015, time=15.1 ms, rem=13.32 s
# iter= 9130, img_loss=0.012694, lap_loss=0.001114, lr=0.00015, time=14.3 ms, rem=12.42 s
# iter= 9140, img_loss=0.011627, lap_loss=0.001115, lr=0.00015, time=14.2 ms, rem=12.21 s
# iter= 9150, img_loss=0.009738, lap_loss=0.001115, lr=0.00015, time=13.7 ms, rem=11.61 s
# iter= 9160, img_loss=0.010485, lap_loss=0.001115, lr=0.00015, time=13.9 ms, rem=11.66 s
# iter= 9170, img_loss=0.011688, lap_loss=0.001115, lr=0.00015, time=13.3 ms, rem=11.04 s
# iter= 9180, img_loss=0.011125, lap_loss=0.001116, lr=0.00015, time=14.1 ms, rem=11.57 s
# iter= 9190, img_loss=0.011782, lap_loss=0.001116, lr=0.00015, time=13.4 ms, rem=10.88 s
# iter= 9200, img_loss=0.010636, lap_loss=0.001116, lr=0.00014, time=13.7 ms, rem=10.95 s
# iter= 9210, img_loss=0.011573, lap_loss=0.001116, lr=0.00014, time=14.0 ms, rem=11.03 s
# iter= 9220, img_loss=0.012055, lap_loss=0.001116, lr=0.00014, time=14.1 ms, rem=11.00 s
# iter= 9230, img_loss=0.010241, lap_loss=0.001117, lr=0.00014, time=13.6 ms, rem=10.50 s
# iter= 9240, img_loss=0.011648, lap_loss=0.001116, lr=0.00014, time=14.6 ms, rem=11.10 s
# iter= 9250, img_loss=0.012844, lap_loss=0.001115, lr=0.00014, time=13.9 ms, rem=10.40 s
# iter= 9260, img_loss=0.011694, lap_loss=0.001115, lr=0.00014, time=14.9 ms, rem=11.04 s
# iter= 9270, img_loss=0.012330, lap_loss=0.001114, lr=0.00014, time=14.5 ms, rem=10.57 s
# iter= 9280, img_loss=0.010240, lap_loss=0.001114, lr=0.00014, time=14.2 ms, rem=10.20 s
# iter= 9290, img_loss=0.011337, lap_loss=0.001113, lr=0.00014, time=14.6 ms, rem=10.37 s
# iter= 9300, img_loss=0.009979, lap_loss=0.001114, lr=0.00014, time=15.5 ms, rem=10.82 s
# iter= 9310, img_loss=0.010642, lap_loss=0.001114, lr=0.00014, time=15.9 ms, rem=10.97 s
# iter= 9320, img_loss=0.012282, lap_loss=0.001114, lr=0.00014, time=16.4 ms, rem=11.14 s
# iter= 9330, img_loss=0.011558, lap_loss=0.001114, lr=0.00014, time=16.5 ms, rem=11.08 s
# iter= 9340, img_loss=0.013606, lap_loss=0.001114, lr=0.00014, time=15.8 ms, rem=10.43 s
# iter= 9350, img_loss=0.010934, lap_loss=0.001115, lr=0.00013, time=14.7 ms, rem=9.54 s
# iter= 9360, img_loss=0.010982, lap_loss=0.001115, lr=0.00013, time=14.1 ms, rem=9.04 s
# iter= 9370, img_loss=0.012519, lap_loss=0.001115, lr=0.00013, time=13.7 ms, rem=8.62 s
# iter= 9380, img_loss=0.009964, lap_loss=0.001115, lr=0.00013, time=14.8 ms, rem=9.16 s
# iter= 9390, img_loss=0.011508, lap_loss=0.001115, lr=0.00013, time=13.7 ms, rem=8.38 s
# iter= 9400, img_loss=0.011012, lap_loss=0.001115, lr=0.00013, time=14.4 ms, rem=8.64 s
# iter= 9410, img_loss=0.011665, lap_loss=0.001115, lr=0.00013, time=13.9 ms, rem=8.18 s
# iter= 9420, img_loss=0.012394, lap_loss=0.001116, lr=0.00013, time=14.7 ms, rem=8.54 s
# iter= 9430, img_loss=0.011600, lap_loss=0.001115, lr=0.00013, time=13.5 ms, rem=7.68 s
# iter= 9440, img_loss=0.011915, lap_loss=0.001115, lr=0.00013, time=13.9 ms, rem=7.79 s
# iter= 9450, img_loss=0.013548, lap_loss=0.001115, lr=0.00013, time=13.9 ms, rem=7.65 s
# iter= 9460, img_loss=0.011168, lap_loss=0.001116, lr=0.00013, time=14.6 ms, rem=7.89 s
# iter= 9470, img_loss=0.010351, lap_loss=0.001116, lr=0.00013, time=13.6 ms, rem=7.21 s
# iter= 9480, img_loss=0.010338, lap_loss=0.001115, lr=0.00013, time=13.8 ms, rem=7.20 s
# iter= 9490, img_loss=0.011850, lap_loss=0.001115, lr=0.00013, time=14.2 ms, rem=7.25 s
# iter= 9500, img_loss=0.012152, lap_loss=0.001116, lr=0.00013, time=14.6 ms, rem=7.28 s
# iter= 9510, img_loss=0.010564, lap_loss=0.001117, lr=0.00013, time=14.2 ms, rem=6.96 s
# iter= 9520, img_loss=0.010388, lap_loss=0.001118, lr=0.00012, time=13.9 ms, rem=6.67 s
# iter= 9530, img_loss=0.014918, lap_loss=0.001118, lr=0.00012, time=20.5 ms, rem=9.65 s
# iter= 9540, img_loss=0.011937, lap_loss=0.001119, lr=0.00012, time=26.6 ms, rem=12.21 s
# iter= 9550, img_loss=0.015057, lap_loss=0.001120, lr=0.00012, time=14.5 ms, rem=6.52 s
# iter= 9560, img_loss=0.010261, lap_loss=0.001120, lr=0.00012, time=16.9 ms, rem=7.44 s
# iter= 9570, img_loss=0.013565, lap_loss=0.001120, lr=0.00012, time=15.5 ms, rem=6.66 s
# iter= 9580, img_loss=0.011076, lap_loss=0.001120, lr=0.00012, time=16.9 ms, rem=7.10 s
# iter= 9590, img_loss=0.012033, lap_loss=0.001120, lr=0.00012, time=16.1 ms, rem=6.58 s
# iter= 9600, img_loss=0.011676, lap_loss=0.001120, lr=0.00012, time=13.9 ms, rem=5.56 s
# iter= 9610, img_loss=0.012699, lap_loss=0.001121, lr=0.00012, time=14.5 ms, rem=5.65 s
# iter= 9620, img_loss=0.012286, lap_loss=0.001122, lr=0.00012, time=13.9 ms, rem=5.28 s
# iter= 9630, img_loss=0.011983, lap_loss=0.001123, lr=0.00012, time=14.0 ms, rem=5.17 s
# iter= 9640, img_loss=0.009364, lap_loss=0.001123, lr=0.00012, time=14.1 ms, rem=5.08 s
# iter= 9650, img_loss=0.011383, lap_loss=0.001123, lr=0.00012, time=14.4 ms, rem=5.05 s
# iter= 9660, img_loss=0.011651, lap_loss=0.001122, lr=0.00012, time=16.6 ms, rem=5.65 s
# iter= 9670, img_loss=0.011807, lap_loss=0.001122, lr=0.00012, time=16.0 ms, rem=5.28 s
# iter= 9680, img_loss=0.012000, lap_loss=0.001121, lr=0.00012, time=15.3 ms, rem=4.89 s
# iter= 9690, img_loss=0.011511, lap_loss=0.001121, lr=0.00012, time=16.7 ms, rem=5.17 s
# iter= 9700, img_loss=0.010587, lap_loss=0.001121, lr=0.00011, time=13.6 ms, rem=4.09 s
# iter= 9710, img_loss=0.009593, lap_loss=0.001120, lr=0.00011, time=14.4 ms, rem=4.17 s
# iter= 9720, img_loss=0.011935, lap_loss=0.001120, lr=0.00011, time=13.9 ms, rem=3.89 s
# iter= 9730, img_loss=0.011514, lap_loss=0.001120, lr=0.00011, time=23.6 ms, rem=6.38 s
# iter= 9740, img_loss=0.011006, lap_loss=0.001120, lr=0.00011, time=18.3 ms, rem=4.76 s
# iter= 9750, img_loss=0.011007, lap_loss=0.001120, lr=0.00011, time=14.7 ms, rem=3.68 s
# iter= 9760, img_loss=0.012208, lap_loss=0.001120, lr=0.00011, time=14.6 ms, rem=3.50 s
# iter= 9770, img_loss=0.012215, lap_loss=0.001121, lr=0.00011, time=14.4 ms, rem=3.31 s
# iter= 9780, img_loss=0.010053, lap_loss=0.001122, lr=0.00011, time=13.6 ms, rem=2.99 s
# iter= 9790, img_loss=0.013802, lap_loss=0.001122, lr=0.00011, time=14.5 ms, rem=3.05 s
# iter= 9800, img_loss=0.011226, lap_loss=0.001122, lr=0.00011, time=13.8 ms, rem=2.76 s
# iter= 9810, img_loss=0.010743, lap_loss=0.001122, lr=0.00011, time=14.2 ms, rem=2.70 s
# iter= 9820, img_loss=0.010457, lap_loss=0.001121, lr=0.00011, time=14.1 ms, rem=2.54 s
# iter= 9830, img_loss=0.011099, lap_loss=0.001120, lr=0.00011, time=15.0 ms, rem=2.54 s
# iter= 9840, img_loss=0.011201, lap_loss=0.001120, lr=0.00011, time=13.8 ms, rem=2.20 s
# iter= 9850, img_loss=0.010199, lap_loss=0.001120, lr=0.00011, time=13.9 ms, rem=2.08 s
# iter= 9860, img_loss=0.009971, lap_loss=0.001120, lr=0.00011, time=13.9 ms, rem=1.95 s
# iter= 9870, img_loss=0.009974, lap_loss=0.001120, lr=0.00011, time=14.4 ms, rem=1.87 s
# iter= 9880, img_loss=0.012966, lap_loss=0.001119, lr=0.00011, time=14.6 ms, rem=1.75 s
# iter= 9890, img_loss=0.011467, lap_loss=0.001119, lr=0.00011, time=14.8 ms, rem=1.63 s
# iter= 9900, img_loss=0.010512, lap_loss=0.001119, lr=0.00010, time=14.3 ms, rem=1.43 s
# iter= 9910, img_loss=0.012733, lap_loss=0.001118, lr=0.00010, time=14.8 ms, rem=1.33 s
# iter= 9920, img_loss=0.010146, lap_loss=0.001118, lr=0.00010, time=15.5 ms, rem=1.24 s
# iter= 9930, img_loss=0.011379, lap_loss=0.001118, lr=0.00010, time=15.3 ms, rem=1.07 s
# iter= 9940, img_loss=0.013852, lap_loss=0.001119, lr=0.00010, time=16.0 ms, rem=0.96 s
# iter= 9950, img_loss=0.012134, lap_loss=0.001119, lr=0.00010, time=16.8 ms, rem=0.84 s
# iter= 9960, img_loss=0.011482, lap_loss=0.001120, lr=0.00010, time=15.3 ms, rem=0.61 s
# iter= 9970, img_loss=0.013220, lap_loss=0.001121, lr=0.00010, time=17.4 ms, rem=0.52 s
# iter= 9980, img_loss=0.011868, lap_loss=0.001121, lr=0.00010, time=16.4 ms, rem=0.33 s
# iter= 9990, img_loss=0.009680, lap_loss=0.001121, lr=0.00010, time=17.9 ms, rem=0.18 s
# iter=10000, img_loss=0.011653, lap_loss=0.001121, lr=0.00010, time=15.6 ms, rem=0.00 s
# Writing mesh:  out/residential_buildings\mesh/mesh.obj
#     writing 1538 vertices
#     writing 1718 texcoords
#     writing 1538 normals
#     writing 3072 faces
# Writing material:  out/residential_buildings\mesh/mesh.mtl
# Done exporting mesh
